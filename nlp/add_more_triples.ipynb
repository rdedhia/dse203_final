# %%
import json
import re
import pandas as pd

# %% [markdown]
# ### Setup

# %%
entity_df = pd.read_json('../wiki_crawler/entities.json', lines=True)

# %%
entity_names = entity_df['name'].unique()

# %%
entity_names
# Out:
# array(['Facebook', 'Summify', 'Periscope (app)', 'Vine (service)',
#        'Pinterest', 'Snapchat', 'WeChat', 'Reddit', 'Instagram',
#        'Twitter', 'Dom Hofmann', 'Libra (cryptocurrency)', 'Oculus VR',
#        'WhatsApp', 'Mike Schroepfer', 'Vancouver', 'Sheryl Sandberg',
#        'Chairperson', 'Menlo Park, California', 'Chris Hughes',
#        'Evan Spiegel', 'Tencent', 'JavaScript',
#        'Scala (programming language)', 'Ruby (programming language)',
#        'Java (programming language)', 'Internet',
#        'Evan Williams (Internet entrepreneur)', 'Omid Kordestani',
#        'Biz Stone', 'Jack Dorsey', 'Multilingualism',
#        'React (web framework)', 'Python (programming language)',
#        'Web banner', 'Online service provider', 'San Francisco',
#        'Chief executive officer', 'Steve Huffman',
#        'Cross-platform software', 'Alexis Ohanian', 'Multimedia',
#        'Aaron Swartz', 'Instant messaging', 'Image sharing', 'Snap Inc.',
#        'Bobby Murphy (businessman)', 'Videotelephony',
#        'Online video platform', 'Wikipedia:Citation needed',
#        'News aggregator', 'Dustin Moskovitz', 'Eduardo Saverin',
#        'Mark Zuckerberg', 'Cambridge, Massachusetts', 'NASDAQ-100',
#        'Advertising', 'Social media'], dtype=object)

# %%
len(entity_names)
# Out:
# 58

# %%
# Add "synonyms" to entity_names
entity_names = list(entity_names) + ['Vine', 'Periscope', 'Libra']

# %%
def filter_entities(cand):
    # Only consider triples if the source node is in the list of entity names
    if cand[0] not in entity_names:
        return False
    
    # Remove edges and target nodes that are too long    
    if len(cand[1].split()) > 4:
         return False
        
    if len(cand[2].split()) > 8:
        return False
    
    # Remove not useful verbs
    if cand[1] in {'is', 'was', 'has', 'be'}:
        return False
    
    return True

# %%
# Generate all potentially useful triple candidates
def gen_triples(triples_raw, filter_flag=True):
    for t in triples_raw.split('\n'):
        trip = t.split(', ')
        if filter_flag:
            if filter_entities(trip):
                print(trip)
        else:
            print(trip)

# %% [markdown]
# ### Facebook

# %%
company = 'Facebook'

# %%
with open(f'{company}.json') as fh:
    data = json.load(fh)

# %%
text = (re.sub('\[\d+\]', '', data['text'].strip()))
with open(f'{company}.txt', 'w') as fh:
    fh.write(text)

# %%
# !rm facebook_triples.txt
# !python Stanford-OpenIE-Python/main.py -f ../facebook.txt > facebook_triples.txt
# Out:
# rm: facebook_triples.txt: No such file or directory

# %%
with open(f'{company}_triples.txt') as fh:
    triples_raw = fh.read()

# %%
# Print triple candidates
gen_triples(triples_raw)
# Out:
# ['Facebook', 'claimed', 'that']
# ['Facebook', 'partnered In', '2017']
# ['Facebook', 'partnered with', 'fact']
# ['Facebook', 'at', 'IPO']
# ['Dustin Moskovitz', 'joined', 'Zuckerberg']
# ['Dustin Moskovitz', 'joined', 'Chris Hughes']
# ['Facebook', 'expanded to', 'Columbia']
# ['Facebook', 'expanded In', 'March 2004']
# ['Facebook', 'hired', 'its intern']
# ['Facebook', 'hired', 'Julie Zhou']
# ['Facebook', 'hired', 'its first intern']
# ['Facebook', 'opened to', 'everyone']
# ['Facebook', 'opened old to', 'everyone']
# ['Facebook', 'opened old On', 'September 26']
# ['Facebook', 'opened On', 'September 26']
# ['Facebook', 'value of', 'around $ 15 billion']
# ['Facebook', 'implied value of', '$ 15 billion']
# ['Facebook', 'total implied value of', '$ 15 billion']
# ['Facebook', 'implied value of', 'around $ 15 billion']
# ['Facebook', 'total value of', '$ 15 billion']
# ['Facebook', 'total value of', 'around $ 15 billion']
# ['Facebook', 'total implied value of', 'around $ 15 billion']
# ['Facebook', 'value of', '$ 15 billion']
# ['Facebook', 'announced In', 'October 2008']
# ['Facebook', 'said In', 'September 2009']
# ['Facebook', 'announced On', 'November 15']
# ['Facebook', 'announced plans In', 'February 2011']
# ['Facebook', 'announced', 'plans']
# ['Facebook', 'reached', 'one trillion page views']
# ['Facebook', 'had According to', 'Nielsen study']
# ['Facebook', 'had in', '2011']
# ['Facebook', 'announced App Center In', 'March 2012']
# ['Facebook', 'announced', 'App Center']
# ['Facebook', 'acquired Instagram for', 'approximately US$ 1 billion']
# ['Facebook', 'acquired Instagram In', 'April 2012']
# ['Facebook', 'acquired', 'Instagram']
# ['Facebook', 'acquired Instagram for', 'approximately US$ 1 billion in cash']
# ['Facebook', 'acquired Instagram for', 'US$ 1 billion in cash']
# ['Facebook', 'acquired Instagram for', 'US$ 1 billion']
# ['Facebook', 'joined Fortune Based on', 'its 2012 income of $ 5 billion']
# ['Facebook', 'joined Fortune Based on', 'its 2012 income']
# ['Facebook', 'ranked', '462']
# ['Facebook', 'had', 'one billion active users including 600 million mobile users']
# ['Facebook', 'had', 'one billion users including 600 million users']
# ['Facebook', 'had', 'one billion users']
# ['Facebook', 'had', 'one billion monthly active users']
# ['Facebook', 'had', 'one billion active users including 600 million users']
# ['Facebook', 'had', 'one billion active users']
# ['Facebook', 'had', 'one billion monthly users including 600 million mobile users']
# ['Facebook', 'had', 'one billion monthly users including 600 million users']
# ['Facebook', 'had', 'one billion users including 600 million mobile users']
# ['Facebook', 'had', 'one billion monthly active users including 600 million users']
# ['Facebook', 'had', 'one billion monthly users']
# ['Facebook', 'had', 'one billion monthly active users including 600 million mobile users']
# ['Facebook', 'unveiled', 'user-interface layer']
# ['Facebook', 'unveiled', 'user-interface layer for Android devices']
# ['Facebook', 'unveiled', 'layer for Android devices']
# ['Facebook', 'unveiled', 'Facebook Home']
# ['Facebook', 'unveiled Facebook Home On', 'April 3']
# ['Facebook', 'unveiled', 'layer']
# ['Facebook', 'alliance across', '19 states with National Association of Attorneys']
# ['Facebook', 'announced', 'alliance across 19 states']
# ['Facebook', 'provide teenagers with', 'information']
# ['Facebook', 'announced', 'alliance']
# ['Facebook', 'announced alliance On', 'April 15']
# ['Facebook', 'provide', 'teenagers']
# ['Facebook', 'provide teenagers with', 'information on tools']
# ['Facebook', 'alliance across', '19 states with National Association']
# ['Facebook', 'alliance across', '19 states']
# ['Facebook', 'announced', 'alliance across 19 states with National Association']
# ['Facebook', 'announced', 'alliance across 19 states with National Association of Attorneys']
# ['Facebook', 'modified', 'its logo']
# ['Facebook', 'update', 'its policy']
# ['Facebook', 'agreed Following', 'campaign by 100 advocacy groups']
# ['Facebook', 'agreed Following', 'campaign']
# ['Facebook', 'announced On', 'June 12']
# ['Facebook', 'joined', 'Alliance']
# ['Facebook', 'joined Alliance for', 'Affordable Internet in October']
# ['Facebook', 'joined Alliance for', 'Affordable Internet']
# ['Facebook', 'joined Alliance for', 'A4AI']
# ['Facebook', 'acquired', 'Israeli web analytics company']
# ['Facebook', 'acquired Onavo On', 'October 13']
# ['Facebook', 'acquired', 'Onavo']
# ['Facebook', 'acquired', 'web analytics company']
# ['Facebook', 'acquired', 'Israeli mobile web analytics company']
# ['Facebook', 'acquired', 'mobile web analytics company']
# ['Facebook', 'announced In', 'February 2014']
# ['Facebook', 'changing', 'its internal motto']
# ['Facebook', 'changing', 'its motto']
# ['Facebook', 'extended paternity leave In', 'November']
# ['Facebook', 'extended paternity leave from', '4 weeks']
# ['Facebook', 'extended paternity leave to', '4 months']
# ['Facebook', 'extended', 'paternity leave']
# ['Facebook', 'announced', 'Text']
# ['Facebook', 'announced', 'Deep Text']
# ['Facebook', 'released', 'its blueprints of Surround 360 camera']
# ['Facebook', 'released', 'its blueprints']
# ['Facebook', 'announced Following', '2016 presidential election']
# ['Facebook', 'announced Following', '2016 election']
# ['Facebook', 'committed On', 'cycle']
# ['Facebook', 'committed', 'work']
# ['Facebook', 'committed On', 'six-month cycle']
# ['Facebook', 'announced', 'beta launch']
# ['Facebook', 'announced', 'beta launch of Facebook Spaces at its annual F8 developer conference']
# ['Facebook', 'announced', 'beta launch of Facebook Spaces at its F8 developer conference']
# ['Facebook', 'announced', 'beta launch at its annual F8 developer conference']
# ['Facebook', 'announced', 'beta launch of Facebook Spaces']
# ['Facebook', 'announced', 'beta launch at its F8 developer conference']
# ['Facebook', 'announced beta launch On', 'April 18']
# ['Facebook', 'announced In', 'September']
# ['Facebook', 'failing', 'respond']
# ['Facebook', 'failing', 'respond to data erasure requests']
# ['Facebook', 'was charged', '# 500,000']
# ['Facebook', 'established subsidiary On', 'July 18']
# ['Facebook', 'established', 'subsidiary named with $ 30 million capital']
# ['Facebook', 'established', 'subsidiary named with $ 30 million of capital']
# ['Facebook', 'established', 'subsidiary named']
# ['Facebook', 'established', 'subsidiary named with $ 30 million']
# ['Facebook', 'established', 'subsidiary']
# ['Facebook', 'became', 'company dropping from $ 630 billion']
# ['Facebook', 'became', 'company dropping']
# ['Facebook', 'became', 'company dropping from nearly $ 630 billion']
# ['Facebook', 'became', 'first company dropping to $ 510 billion after sales reports']
# ['Facebook', 'became', 'first company dropping from nearly $ 630 billion']
# ['Facebook', 'became', 'company dropping from nearly $ 630 billion after disappointing sales reports']
# ['Facebook', 'became', 'first company dropping from $ 630 billion after disappointing sales reports']
# ['Facebook', 'became', 'company dropping after disappointing sales reports']
# ['Facebook', 'became', 'company dropping from $ 630 billion after disappointing sales reports']
# ['Facebook', 'became', 'first company dropping after sales reports']
# ['Facebook', 'became', 'company dropping from $ 630 billion to $ 510 billion after disappointing sales reports']
# ['Facebook', 'became', 'company dropping from nearly $ 630 billion after sales reports']
# ['Facebook', 'became', 'first company dropping from $ 630 billion to $ 510 billion after sales reports']
# ['Facebook', 'became', 'company dropping after sales reports']
# ['Facebook', 'became', 'company dropping from $ 630 billion to $ 510 billion']
# ['Facebook', 'became', 'first company dropping from nearly $ 630 billion after disappointing sales reports']
# ['Facebook', 'became', 'first company dropping from $ 630 billion to $ 510 billion after disappointing sales reports']
# ['Facebook', 'became', 'first company dropping from $ 630 billion after sales reports']
# ['Facebook', 'became', 'company']
# ['Facebook', 'became', 'company dropping from $ 630 billion to $ 510 billion after sales reports']
# ['Facebook', 'became', 'first company dropping to $ 510 billion after disappointing sales reports']
# ['Facebook', 'became', 'first company dropping']
# ['Facebook', 'became', 'company dropping to $ 510 billion after disappointing sales reports']
# ['Facebook', 'became', 'company dropping to $ 510 billion']
# ['Facebook', 'became', 'first company']
# ['Facebook', 'became', 'first company dropping from $ 630 billion']
# ['Facebook', 'became', 'first company dropping from nearly $ 630 billion to $ 510 billion after sales reports']
# ['Facebook', 'became', 'first company dropping to $ 510 billion']
# ['Facebook', 'became', 'first company dropping after disappointing sales reports']
# ['Facebook', 'became company On', 'July 26']
# ['Facebook', 'became', 'company dropping from nearly $ 630 billion to $ 510 billion after disappointing sales reports']
# ['Facebook', 'became', 'company dropping to $ 510 billion after sales reports']
# ['Facebook', 'became', 'first company dropping from nearly $ 630 billion to $ 510 billion']
# ['Facebook', 'became', 'company dropping from nearly $ 630 billion to $ 510 billion']
# ['Facebook', 'became', 'first company dropping from nearly $ 630 billion after sales reports']
# ['Facebook', 'became', 'first company dropping from $ 630 billion to $ 510 billion']
# ['Facebook', 'became', 'company dropping from nearly $ 630 billion to $ 510 billion after sales reports']
# ['Facebook', 'became', 'first company dropping from nearly $ 630 billion to $ 510 billion after disappointing sales reports']
# ['Facebook', 'became', 'company dropping from $ 630 billion after sales reports']
# ['Facebook', 'said On', 'July 31']
# ['Facebook', 'announced On', 'September 19']
# ['Facebook', 'launched', 'displays']
# ['Facebook', 'launched displays In', 'November']
# ['Facebook', 'launched', 'smart displays']
# ['Facebook', 'Criticized for', 'its role in vaccine hesitancy']
# ['Facebook', 'Criticized for', 'its role']
# ['Facebook', 'announced in', 'March 2019']
# ['Facebook', 'took', '29 minutes']
# ['Facebook', 'detect', 'livestreamed video']
# ['Facebook', 'detect', 'video']
# ['Facebook', 'began Following', 'attack']
# ['Facebook', 'blocking', 'white nationalist']
# ['Facebook', 'blocking', 'nationalist']
# ['Facebook', 'had only blocked', 'content']
# ['Facebook', 'had blocked', 'overtly supremacist content']
# ['Facebook', 'Previously had only blocked', 'overtly supremacist content']
# ['Facebook', 'Previously had blocked', 'content']
# ['Facebook', 'had only blocked', 'overtly supremacist content']
# ['Facebook', 'had only blocked', 'supremacist content']
# ['Facebook', 'Previously had only blocked', 'supremacist content']
# ['Facebook', 'Previously had blocked', 'supremacist content']
# ['Facebook', 'had blocked', 'content']
# ['Facebook', 'Previously had blocked', 'overtly supremacist content']
# ['Facebook', 'had blocked', 'supremacist content']
# ['Facebook', 'Previously had only blocked', 'content']
# ['Facebook', 'founded', 'Libra Networks']
# ['Facebook', 'founded Libra Networks In', 'May 2019']
# ['Facebook', 'announced partnership On', 'July 31']
# ['Facebook', 'announced', 'partnership with University']
# ['Facebook', 'announced', 'partnership']
# ['Facebook', 'announced', 'partnership with University of California']
# ['Facebook', 'launched Facebook Dating On', 'September 5']
# ['Facebook', 'launched Facebook Dating in', 'United States']
# ['Facebook', 'launched', 'Facebook Dating']
# ['Facebook', 'is developed as', 'one monolithic application']
# ['Facebook', 'is developed as', 'one application']
# ['Facebook', 'used', 'combination platform based on HBase']
# ['Facebook', 'used', 'combination platform based']
# ['Facebook', 'used', 'combination platform']
# ['Facebook', 'handles', 'requests']
# ['Facebook', 'handles', 'requests as AJAX behavior']
# ['Facebook', 'announced', 'new programming language']
# ['Facebook', 'announced programming language On', 'March 20 2014']
# ['Facebook', 'announced', 'new programming language called']
# ['Facebook', 'announced', 'programming language called']
# ['Facebook', 'announced', 'programming language']
# ['Facebook', 'announced', 'open-source programming language']
# ['Facebook', 'announced', 'open-source programming language called']
# ['Facebook', 'announced', 'new open-source programming language called']
# ['Facebook', 'announced', 'new open-source programming language']
# ['Facebook', 'introduced', 'redesign of its user interface on selected networks']
# ['Facebook', 'introduced', 'significant redesign of its user interface on networks']
# ['Facebook', 'introduced', 'redesign of its user interface on networks']
# ['Facebook', 'introduced', 'redesign of its user interface']
# ['Facebook', 'introduced', 'significant redesign on networks']
# ['Facebook', 'introduced', 'significant redesign']
# ['Facebook', 'introduced', 'redesign on networks']
# ['Facebook', 'introduced', 'significant redesign of its user interface']
# ['Facebook', 'introduced', 'redesign']
# ['Facebook', 'introduced', 'redesign on selected networks']
# ['Facebook', 'introduced', 'significant redesign on selected networks']
# ['Facebook', 'introduced Facebook Beta On', 'July 20']
# ['Facebook', 'introduced', 'significant redesign of its user interface on selected networks']
# ['Facebook', 'introduced', 'Facebook Beta']
# ['Facebook', 'migrating users to', 'new version in September 2008']
# ['Facebook', 'migrating users to', 'new version']
# ['Facebook', 'migrating users to', 'version']
# ['Facebook', 'migrating', 'users']
# ['Facebook', 'migrating users to', 'version in September 2008']
# ['Facebook', 'launched Facebook Pages In', '2007']
# ['Facebook', 'launched', 'Facebook Pages for brands']
# ['Facebook', 'launched', 'Facebook Pages']
# ['Facebook', 'interact with', 'their fanbase']
# ['Facebook', 'introduced Usernames feature In', 'June 2009']
# ['Facebook', 'introduced', 'Usernames feature for sharing']
# ['Facebook', 'introduced', 'Usernames feature allowing']
# ['Facebook', 'introduced', 'Usernames feature allowing for sharing']
# ['Facebook', 'introduced', 'Usernames feature for easier sharing']
# ['Facebook', 'introduced', 'Usernames feature allowing for easier sharing']
# ['Facebook', 'introduced', 'Usernames feature']
# ['Facebook', 'expanded gender setting In', 'February 2014']
# ['Facebook', 'expanded', 'gender setting']
# ['Facebook', 'introduced feature In', 'May 2014']
# ['Facebook', 'introduced', 'feature']
# ['Facebook', 'was granted', 'patent on aspects']
# ['Facebook', 'was granted', 'patent']
# ['Facebook', 'was granted', 'patent on certain aspects of its News Feed']
# ['Facebook', 'was granted', 'patent on certain aspects']
# ['Facebook', 'was granted', 'patent on aspects of its News Feed']
# ['Facebook', 'was granted patent On', 'February 23 2010']
# ['Facebook', 'launched', 'its App Center']
# ['Facebook', 'launched', 'Articles']
# ['Facebook', 'launched', 'Instant Articles']
# ['Facebook', 'provide', 'news on Facebook news feed']
# ['Facebook', 'is with', 'major news portals']
# ['Facebook', 'provide', 'news']
# ['Facebook', 'is in', 'association']
# ['Facebook', 'launched Articles On', 'May 13 2015']
# ['Facebook', 'launched Facebook Stories In', 'January 2017']
# ['Facebook', 'launched Facebook Stories for', 'iOS in Ireland']
# ['Facebook', 'launched', 'Facebook Stories']
# ['Facebook', 'launched Facebook Stories for', 'iOS']
# ['Facebook', 'introduced On', 'October 11 2017']
# ['Facebook', 'announced On', 'January 11 2018']
# ['Facebook', 'choosing among', 'five pre-defined emotions including Love']
# ['Facebook', 'choosing among', 'five emotions']
# ['Facebook', 'expanded Like', 'Like Reactions']
# ['Facebook', 'expanded', 'choosing among five emotions including Love']
# ['Facebook', 'choosing among', 'five pre-defined emotions']
# ['Facebook', 'expanded', 'choosing among five pre-defined emotions including Love']
# ['Facebook', 'expanded', 'choosing among five emotions']
# ['Facebook', 'choosing among', 'five emotions including Love']
# ['Facebook', 'expanded', 'choosing']
# ['Facebook', 'expanded', 'choosing among five pre-defined emotions']
# ['Facebook', 'added', 'Messenger Day']
# ['Facebook', 'enables', 'users']
# ['Facebook', 'passed', '100 million users']
# ['Facebook', 'passed', '100 million registered users']
# ['Facebook', 'uses', 'Facebook Messenger app']
# ['Facebook', 'changed', 'its definition']
# ['Facebook', 'won', 'Crunchie Startup']
# ['Facebook', 'won', 'Crunchie Best Overall Startup']
# ['Facebook', 'won Crunchie Startup for', 'year']
# ['Facebook', 'won', 'Crunchie Overall Startup']
# ['Facebook', 'won Crunchie Startup for', 'year in row']
# ['Facebook', 'won Crunchie Startup for', 'third year in row']
# ['Facebook', 'won Crunchie Startup for', 'third year']
# ['Facebook', 'won', 'Crunchie Best Startup']
# ['Facebook', 'won Crunchie Startup In', '2010']
# ['Facebook', 'have', 'psychological effects']
# ['Facebook', 'have effects including', 'feelings of jealousy']
# ['Facebook', 'have', 'effects']
# ['Facebook', 'have effects including', 'feelings']
# ['Facebook', 'have effects including', 'lack']
# ['Facebook', 'have effects including', 'lack of attention']
# ['Facebook', 'allowing', 'users']
# ['Facebook', 'avoided', 'billions of dollars in tax']
# ['Facebook', 'avoided', 'billions']
# ['Facebook', 'avoided', 'billions in tax']
# ['Facebook', 'avoided billions According to', 'Express Tribune']
# ['Facebook', 'avoided', 'billions of dollars']
# ['Facebook', 'removed during', 'quarter of 2018']
# ['Facebook', 'removed during', 'only quarter']
# ['Facebook', 'removed during', 'last quarter']
# ['Facebook', 'removed', '3 billion fake accounts']
# ['Facebook', 'removed during', 'only quarter of 2018']
# ['Facebook', 'removed during', 'only last quarter']
# ['Facebook', 'removed during', 'last quarter of 2018']
# ['Facebook', 'quarter of', '2019']
# ['Facebook', 'removed during', 'quarter']
# ['Facebook', 'removed during', 'only last quarter of 2018']
# ['Facebook', 'first quarter of', '2019']
# ['Facebook', 'repeatedly adjusting', 'its privacy settings']
# ['Facebook', 'has faced', 'stream of controversies']
# ['Facebook', 'has faced', 'steady stream of controversies']
# ['Facebook', 'adjusting', 'its privacy settings']
# ['Facebook', 'has faced', 'steady stream']
# ['Facebook', 'has faced', 'stream']
# ['Facebook', 'settled On', 'November 29']
# ['Facebook', 'announced On', 'June 7']
# ['Facebook', 'issued', 'statement']
# ['Facebook', 'of', 'consent decree with Federal Trade Commission']
# ['Facebook', 'claimed After', 'publication']
# ['Facebook', 'published statement in', 'UK apologizing']
# ['Facebook', 'published statement by', 'Zuckerberg']
# ['Facebook', 'published statement in', 'major UK apologizing over breach']
# ['Facebook', 'published statement in', 'UK']
# ['Facebook', 'published statement On', 'March 25']
# ['Facebook', 'published statement in', 'major UK apologizing over breach of trust']
# ['Facebook', 'published statement in', 'major UK']
# ['Facebook', 'published statement in', 'UK apologizing over breach of trust']
# ['Facebook', 'published statement in', 'UK apologizing over breach']
# ['Facebook', 'published statement in', 'major UK apologizing']
# ['Facebook', 'published', 'statement']
# ['Facebook', 'said On', 'April 24']
# ['Facebook', 'also implemented', 'additional privacy controls']
# ['Facebook', 'also implemented privacy controls in', 'part']
# ['Facebook', 'implemented', 'privacy controls']
# ['Facebook', 'implemented', 'additional privacy controls']
# ['Facebook', 'implemented privacy controls in', 'part']
# ['Facebook', 'implemented privacy controls in', 'part comply']
# ['Facebook', 'also implemented privacy controls in', 'part comply']
# ['Facebook', 'also implemented', 'privacy controls']
# ['Facebook', 'ended', 'its opposition']
# ['Facebook', 'ended', 'its active opposition to California Consumer Privacy Act']
# ['Facebook', 'also ended', 'its active opposition to California Consumer Privacy Act']
# ['Facebook', 'also ended', 'its opposition']
# ['Facebook', 'ended', 'its active opposition']
# ['Facebook', 'ended', 'its opposition to California Consumer Privacy Act']
# ['Facebook', 'also ended', 'its opposition to California Consumer Privacy Act']
# ['Facebook', 'also ended', 'its active opposition']
# ['Facebook', 'breach in', 'its security']
# ['Facebook', 'major breach in', 'its security']
# ['Facebook', 'experienced breach On', 'September 28']
# ['Facebook', 'experienced', 'breach']
# ['Facebook', 'exposing', 'data of 50 million users']
# ['Facebook', 'experienced', 'breach in its security']
# ['Facebook', 'exposing', 'data']
# ['Facebook', 'experienced', 'major breach in its security']
# ['Facebook', 'experienced', 'major breach']
# ['Facebook', 'notified', 'users affected']
# ['Facebook', 'logged', 'them']
# ['Facebook', 'notified', 'users affected by exploit']
# ['Facebook', 'notified', 'users']
# ['Facebook', 'confirmed', 'password compromise of millions']
# ['Facebook', 'confirmed', 'password compromise']
# ['Facebook', 'confirmed', 'password compromise of millions of Facebook lite application users']
# ['Facebook', 'confirmed password compromise In', 'March 2019']
# ['Facebook', 'used', 'Onavo Protect virtual network']
# ['Facebook', 'used', 'Onavo Protect virtual private network']
# ['Facebook', 'used', 'VPN']
# ['Facebook', 'monitor', "its competitors ' performance"]
# ['Facebook', 'removed In', 'August 2018']
# ['Facebook', 'removed app in', 'response']
# ['Facebook', 'removed in', 'response']
# ['Facebook', 'removed app In', 'August 2018']
# ['Facebook', 'removed app in', 'response to pressure']
# ['Facebook', 'removed', 'app']
# ['Facebook', 'removed in', 'response to pressure']
# ['Facebook', 'put', 'all its privacy settings']
# ['Facebook', 'now put', 'all its privacy settings']
# ['Facebook', 'put', 'all privacy settings']
# ['Facebook', 'now put', 'all privacy settings']
# ['Facebook', 'put', 'all of privacy settings']
# ['Facebook', 'now put', 'all of its privacy settings']
# ['Facebook', 'now put', 'all of privacy settings']
# ['Facebook', 'put', 'all of its privacy settings']
# ['Facebook', 'generate', 'content']
# ['Facebook', 'relies on', 'its users']
# ['Facebook', 'has repeatedly amended', 'its content policies']
# ['Facebook', 'has amended', 'its policies']
# ['Facebook', 'has repeatedly amended', 'its policies']
# ['Facebook', 'has amended', 'its content policies']
# ['Facebook', 'banned', 'number']
# ['Facebook', 'banned', 'number of commentators including Alex Jones engaging in violence']
# ['Facebook', 'banned', 'number of commentators including Alex Jones allegedly engaging']
# ['Facebook', 'banned', 'number of commentators including Alex Jones']
# ['Facebook', 'banned', 'number of commentators including Alex Jones engaging']
# ['Facebook', 'banned number In', 'May 2019']
# ['Facebook', 'banned', 'number of commentators including Alex Jones allegedly engaging in violence']
# ['Facebook', 'banned', 'number of commentators']
# ['Facebook', 'allowing', 'InfoWars']
# ['Facebook', 'defended', 'its actions']
# ['Facebook', 'had', 'even had contacted about videos']
# ['Facebook', 'had', 'even had contacted']
# ['Facebook', 'had', 'had contacted']
# ['Facebook', 'had', 'had contacted about videos']
# ['Facebook', 'remove', 'InfoWars content']
# ['Facebook', 'allowed despite', 'assertions']
# ['Facebook', 'also allowed despite', 'specific assertions']
# ['Facebook', 'also allowed despite', 'assertions']
# ['Facebook', 'allowed despite', 'specific assertions']
# ['Facebook', 'suspended profile In', 'July']
# ['Facebook', 'suspended', 'profile']
# ['Facebook', 'suspended', 'personal profile']
# ['Facebook', 'suspended profile In', 'late July']
# ['Facebook', 'banned', 'four Infowars-related pages']
# ['Facebook', 'banned', 'four active Infowars-related pages']
# ['Facebook', 'banned', 'four active pages']
# ['Facebook', 'banned', 'four pages']
# ['Facebook', 'banned', 'four most active Infowars-related pages']
# ['Facebook', 'banned', 'four most active pages']
# ['Facebook', 'stated In', '2018']
# ['Facebook', 'said In', 'January 2019']
# ['Facebook', 'found', 'fake users']
# ['Facebook', 'gave', 'examples of Archimedes Group interference in Nigeria']
# ['Facebook', 'gave', 'examples']
# ['Facebook', 'gave', 'examples of Archimedes Group political interference in Nigeria']
# ['Facebook', 'gave', 'examples of Archimedes Group political interference']
# ['Facebook', 'gave', 'examples of Archimedes Group interference']
# ['Facebook', 'released', 'its Community Standards Enforcement Report highlighting']
# ['Facebook', 'released', 'its Community Standards Enforcement Report']
# ['Facebook', 'counter', 'deceptive propaganda']
# ['Facebook', 'advanced', 'its measures']
# ['Facebook', 'counter', 'deceptive political propaganda']
# ['Facebook', 'counter', 'political propaganda']
# ['Facebook', 'counter', 'propaganda']
# ['Facebook', 'deleted', 'accounts of employees working at Israeli NSO Group']
# ['Facebook', 'deleted', 'several accounts of employees working at Israeli NSO Group']
# ['Facebook', 'deleted', 'accounts of employees working']
# ['Facebook', 'deleted', 'accounts of employees']
# ['Facebook', 'deleted', 'several accounts']
# ['Facebook', 'deleted', 'several accounts of employees']
# ['Facebook', 'deleted', 'several accounts of employees working at NSO Group']
# ['Facebook', 'deleted', 'several accounts of employees working']
# ['Facebook', 'deleted', 'accounts']
# ['Facebook', 'deleted', 'accounts of employees working at NSO Group']
# ['Facebook', 'deleted accounts On', 'October 30 2019']
# ['WhatsApp', 'sued', 'Israeli surveillance firm']
# ['WhatsApp', 'targeting', '1,400 devices']
# ['WhatsApp', 'sued', 'surveillance firm']
# ['WhatsApp', 'targeting', '1,400 devices with spyware']
# ['Facebook', 'removed', '289 Pages']
# ['Facebook', 'removed In', 'January 2019']
# ['Facebook', 'removed', '289 Pages linked']
# ['Facebook', 'is in', 'India']
# ['Facebook', 'mishandling by', 'hate speech']
# ['Facebook', 'expanded', 'its work with Definers Public Affairs']
# ['Facebook', 'mishandling by', 'hate speech on Facebook']
# ['Facebook', 'mishandling by', 'Cambridge Analytica']
# ['Facebook', 'expanded', 'its work']
# ['Facebook', 'mishandling of', 'user data']
# ['Facebook', 'cut', 'ties with agency']
# ['Facebook', 'cut ties in', 'late 2018']
# ['Facebook', 'cut ties following', 'outcry']
# ['Facebook', 'cut ties following', 'public outcry']
# ['Facebook', 'cut ties following', 'outcry over their association']
# ['Facebook', 'cut ties following', 'public outcry over their association']
# ['Facebook', 'cut', 'ties']
# ['Facebook', 'enlisted', 'hundreds of contractors']
# ['Facebook', 'hundreds of', 'contractors']
# ['Facebook', 'enlisted', 'hundreds']
# ['Facebook', 'released', 'statement']
# ['Facebook', 'massive depository of', 'information']
# ['Facebook', 'constitutes', 'depository']
# ['Facebook', 'constitutes', 'depository of information']
# ['Facebook', 'constitutes', 'massive depository']
# ['Facebook', 'constitutes', 'massive depository of information']
# ['Facebook', 'depository of', 'information']
# ['Facebook', 'reduce', 'its carbon impact']
# ['Facebook', 'lets despite', 'actual distance involved']
# ['Facebook', 'lets despite', 'actual distance']
# ['Facebook', 'lets despite', 'distance']
# ['Facebook', 'lets despite', 'distance involved']
# ['Facebook', 'is with', 'feelings of envy']
# ['Facebook', 'became', 'primary tool for connecting protesters']
# ['Facebook', 'became', 'primary tool']
# ['Facebook', 'became', 'tool']
# ['Facebook', 'became', 'tool for connecting protesters']
# ['Facebook', 'led', 'Egyptian government']
# ['Facebook', 'became in', 'Tunisia']
# ['Facebook', 'primary tool for', 'protesters']
# ['Facebook', 'became', 'tool for protesters']
# ['Facebook', 'tool for', 'protesters']
# ['Facebook', 'ban', 'websites']
# ['Facebook', 'led', 'government']
# ['Facebook', 'became', 'primary tool for protesters']
# ['Facebook', 'primary tool for', 'connecting protesters']
# ['Facebook', 'ban', 'other websites']
# ['Facebook', 'ban', 'Twitter']
# ['Facebook', 'tool for', 'connecting protesters']
# ['Facebook', 'was utilized by', 'Bahraini regime']
# ['Facebook', 'was utilized', 'identify']
# ['Facebook', 'was utilized on', 'February 14 2011']
# ['Facebook', 'form', 'political action committee']
# ['Facebook', 'form', 'action committee']
# ['Facebook', 'filed paperwork with', 'Federal Election Commission']
# ['Facebook', 'form action committee under', 'name FB PAC']
# ['Facebook', 'filed', 'paperwork']
# ['Facebook', 'filed paperwork In', '2011']
# ['Facebook', 'first played role before', 'New Hampshire primary']
# ['Facebook', 'first played role in', 'American political process in January 2008']
# ['Facebook', 'first played role in', 'American process in January 2008']
# ['Facebook', 'first played role in', 'process']
# ['Facebook', 'played role in', 'political process in January 2008']
# ['Facebook', 'played role in', 'American political process']
# ['Facebook', 'played role in', 'process']
# ['Facebook', 'first played role in', 'political process']
# ['Facebook', 'played role in', 'American process in January 2008']
# ['Facebook', 'first played role in', 'process in January 2008']
# ['Facebook', 'first played', 'role']
# ['Facebook', 'played role in', 'political process']
# ['Facebook', 'played role in', 'American process']
# ['Facebook', 'first played role in', 'political process in January 2008']
# ['Facebook', 'played role in', 'American political process in January 2008']
# ['Facebook', 'played role before', 'shortly New Hampshire primary']
# ['Facebook', 'first played role before', 'shortly New Hampshire primary']
# ['Facebook', 'first played role in', 'American process']
# ['Facebook', 'played role in', 'process in January 2008']
# ['Facebook', 'played', 'role']
# ['Facebook', 'played role before', 'New Hampshire primary']
# ['Facebook', 'first played role in', 'American political process']
# ['Facebook', 'allow', 'users']
# ['Facebook', 'such as media is', 'connected hundreds of millions of people']
# ['Facebook', 'offered', 'targeting']
# ['Facebook', 'offered', 'most sophisticated targeting']
# ['Facebook', 'offered', 'sophisticated targeting']
# ['Facebook', 'has removed', '103 pages']
# ['Facebook', 'has removed', '103 pages on Facebook originating from Pakistan']
# ['Facebook', 'has removed', '103 pages on Facebook originating']
# ['Facebook', 'has removed', '103 pages on Facebook']
# ['Facebook', 'Owing to', 'same reasons']
# ['Facebook', 'removed because of', 'coordinated inauthentic behavior']
# ['Facebook', 'removed because of', 'coordinated behavior']
# ['Facebook', 'also removed because of', 'inauthentic behavior']
# ['Facebook', 'also removed because of', 'behavior on platform']
# ['Facebook', 'also removed', '687 pages']
# ['Facebook', 'removed', '687 pages']
# ['Facebook', 'also removed because of', 'inauthentic behavior on platform']
# ['Facebook', 'removed because of', 'inauthentic behavior on platform']
# ['Facebook', 'removed because of', 'coordinated behavior on platform']
# ['Facebook', 'also removed because of', 'coordinated behavior on platform']
# ['Facebook', 'Owing to', 'reasons']
# ['Facebook', 'also removed because of', 'coordinated behavior']
# ['Facebook', 'also removed because of', 'behavior']
# ['Facebook', 'also removed', '687 pages of Congress']
# ['Facebook', 'removed because of', 'coordinated inauthentic behavior on platform']
# ['Facebook', 'removed', '687 pages of Congress']
# ['Facebook', 'removed because of', 'behavior']
# ['Facebook', 'removed because of', 'behavior on platform']
# ['Facebook', 'also removed because of', 'coordinated inauthentic behavior']
# ['Facebook', 'removed because of', 'inauthentic behavior']
# ['Facebook', 'also removed because of', 'coordinated inauthentic behavior on platform']
# ['Facebook', 'established', 'Social Science One']
# ['Facebook', 'have', 'have subject of music']
# ['Facebook', 'have', 'have subject']
# ['Facebook', 'founded Internet.org in', 'collaboration with six other technology companies plan']
# ['Facebook', 'founded Internet.org in', 'collaboration with six other technology companies']
# ['Facebook', 'founded', 'Internet.org']
# ['Facebook', 'founded Internet.org in', 'collaboration with six technology companies']
# ['Facebook', 'founded Internet.org in', 'collaboration']
# ['Facebook', 'founded Internet.org In', 'August 2013']
# ['Facebook', 'founded Internet.org in', 'collaboration plan']
# ['Facebook', 'founded Internet.org in', 'collaboration with six technology companies plan']

# %%
# Manual inspection revealed these as better triple candidates
'''
['Facebook', 'acquired', 'Instagram']
['Facebook', 'acquired', 'Onavo']
['Facebook', 'founded', 'Libra Networks']
['Facebook', 'won', 'Crunchie Best Startup']
['Facebook', 'exposing', 'data of 50 million users']
['WhatsApp', 'sued', 'Israeli surveillance firm']
['Facebook', 'banned', 'number of commentators including Alex Jones']
['Facebook', 'mishandling by', 'Cambridge Analytica']
['Facebook', 'founded', 'Internet.org']
'''
# Out:
# "\n['Facebook', 'acquired', 'Instagram']\n['Facebook', 'acquired', 'Onavo']\n['Facebook', 'founded', 'Libra Networks']\n['Facebook', 'won', 'Crunchie Best Startup']\n['Facebook', 'exposing', 'data of 50 million users']\n['WhatsApp', 'sued', 'Israeli surveillance firm']\n['Facebook', 'banned', 'number of commentators including Alex Jones']\n['Facebook', 'mishandling by', 'Cambridge Analytica']\n['Facebook', 'founded', 'Internet.org']\n"

# %%
# Formatted Candidates
fb_entities = [
    ['Facebook', 'acquired', ['Instagram', 'Onavo']],
    ['Facebook', 'founded', ['Libra Networks', 'Internet.org']],
    ['Facebook', 'associated_with', ['Cambridge Analytica']],
    ['Facebook', 'won', ['Crunchie Best Startup']],
    ['Facebook', 'banned', ['Alex Jones']],
    ['Facebook', 'breached_data', '50 million'],
    ['WhatsApp', 'sued', 'Israeli surveillance firm']
]

# %% [markdown]
# ### Vine

# %%
company = 'Vine'
with open(f'{company}.json') as fh:
    data = json.load(fh)
    
text = (re.sub('\[\d+\]', '', data['text'].strip()))
with open(f'{company}.txt', 'w') as fh:
    fh.write(text)

# %%
# !rm vine_triples.txt
# !python Stanford-OpenIE-Python/main.py -f ../vine.txt > vine_triples.txt
# Out:
# rm: vine_triples.txt: No such file or directory

# %%
with open(f'{company}_triples.txt') as fh:
    triples_raw = fh.read()
    
gen_triples(triples_raw)
# Out:
# ['Vine', 'through', 'social network']
# ['Vine', 'competed with', 'social-media services']
# ['Vine', 'competed with', 'other services']
# ['Vine', 'competed with', 'services']
# ['Vine', 'competed with', 'other social-media services']
# ['Vine', 'had', '200 million users']
# ['Vine', 'had', '200 million active users']
# ['Twitter', 'announced On', 'October 27 2016']
# ['Twitter', 'allowing', 'people']
# ['Twitter', 'launched', 'Internet archive of Vine videos']
# ['Vine', "'s successor is", 'V2']
# ['Vine', 'on', 'successor']
# ['Vine', 'launched as', 'app for iOS devices']
# ['Vine', 'launched as', 'free app for iOS devices']
# ['Vine', 'launched on', 'January 24 2013']
# ['Vine', 'launched as', 'free app']
# ['Vine', 'launched as', 'app']
# ['Vine', 'became video with', 'low adoption of app']
# ['Vine', 'became', 'used video']
# ['Vine', 'became video with', 'even low adoption']
# ['Vine', 'became video with', 'even adoption']
# ['Vine', 'became video with', 'adoption']
# ['Vine', 'became video with', 'even low adoption of app']
# ['Vine', 'became video In', 'couple']
# ['Vine', 'became video In', 'couple of months']
# ['Vine', 'became video with', 'even adoption of app']
# ['Vine', 'became', 'most used video']
# ['Vine', 'became video with', 'adoption of app']
# ['Vine', 'became video with', 'low adoption']
# ['Vine', 'became', 'video']
# ['Vine', 'explore', 'videos']
# ['Vine', 'updated', 'its app']
# ['Vine', 'updated In', 'July 2014']
# ['Vine', 'announced In', 'June 2016']
# ['Vine', 'launched', 'app designed']
# ['Vine', 'launched', 'app designed for children']
# ['Vine', 'launched', 'app']
# ['Vine', 'launched Vine Kids In', 'January 2015']
# ['Vine', 'launched', 'Vine Kids']
# ['Vine', 'launched', 'app designed specifically for children']
# ['Vine', "'s Head is", 'Carolyn Penner']
# ['Vine', 'announced On', 'October 27 2016']
# ['Twitter', 'discontinuing', 'Vine mobile app']
# ['Twitter', 'discontinuing', 'Vine app']
# ['Vine', 'to', 'short-form video approach']
# ['Twitter', 'to', 'discontinuation of service']
# ['Twitter', 'allowing', 'people']
# ['Twitter', 'launched', 'Internet archive of Vine videos']
# ['Twitter', 'allowing', 'continue']
# ['Vine', 'enabled', 'users']
# ['Vine', 'stop', 'motion animation']
# ['Vine', 'different types of', 'uses']
# ['Vine', 'types of', 'uses']
# ['Vine', 'document', 'aftermath']
# ['Vine', 'document', 'aftermath of 2013 United States embassy bombing']
# ['Vine', 'document', 'aftermath of 2013 United States embassy bombing in Ankara']
# ['Vine', 'being space', 'that allowed for creatives thrive']
# ['Vine', 'being space', 'that allowed for black creatives']
# ['Vine', 'being space', 'that allowed']
# ['Vine', 'being space', 'that allowed for black creatives thrive']
# ['Vine', 'being space', 'that allowed for creatives']
# ['Vine', 'was listed among', "Time 's '50 Android Apps for 2013"]
# ['Vine', 'was listed among', "Time 's '50 Best Android Apps for 2013"]
# ['Vine', 'was listed among', "Time 's '50 Android Apps"]
# ['Vine', 'was listed among', "Time 's '50 Best Android Apps"]
# ['Instagram', 'added', '15-second video sharing']
# ['Instagram', 'added video sharing in', 'June 2013']
# ['Instagram', 'added', 'video sharing']
# ['Instagram', 'added in', 'June 2013']
# ['Snapchat', 'added', '10-second video sharing']
# ['Snapchat', 'added', 'video sharing']
# ['Snapchat', 'added', '10-second video']
# ['Snapchat', 'added', 'video']
# ['Snapchat', 'added', '10-second video sharing on December 2012']
# ['Snapchat', 'added', 'video sharing on December 2012']

# %%
vine_entities = [
    ['Vine (service)', 'launched', 'Vine Kids'],
    ['Vine (service)', 'won', "Time's '50 Android Apps"]
]

# %% [markdown]
# ### Snapchat

# %%
company = 'Snapchat'
with open(f'{company}.json') as fh:
    data = json.load(fh)
    
text = (re.sub('\[\d+\]', '', data['text'].strip()))
with open(f'{company}.txt', 'w') as fh:
    fh.write(text)

# %%
# !rm snapchat_triples.txt
# !python Stanford-OpenIE-Python/main.py -f ../snapchat.txt > snapchat_triples.txt
# Out:
# rm: snapchat_triples.txt: No such file or directory

# %%
with open(f'{company}_triples.txt') as fh:
    triples_raw = fh.read()
    
gen_triples(triples_raw)
# Out:
# ['Snapchat', 'places', 'significant emphasis']
# ['Snapchat', 'has become', 'known']
# ['Snapchat', 'places', 'emphasis on users interacting with virtual stickers']
# ['Snapchat', 'places', 'emphasis on users']
# ['Snapchat', 'places', 'significant emphasis on users']
# ['Snapchat', 'places', 'significant emphasis on users interacting']
# ['Snapchat', 'places', 'emphasis']
# ['Snapchat', 'places', 'emphasis on users interacting']
# ['Snapchat', 'places', 'significant emphasis on users interacting with virtual stickers']
# ['Snapchat', 'was experiencing', 'difficulties']
# ['Snapchat', 'was released as', 'Android app on October 29 2012']
# ['Snapchat', 'was released as', 'Android app']
# ['Snapchat', 'Also introduced Snapkidz under', '13 years of age']
# ['Snapchat', 'introduced Snapkidz under', '13 years']
# ['Snapchat', 'Also introduced Snapkidz in', 'June 2013']
# ['Snapchat', 'introduced Snapkidz under', '13 years of age']
# ['Snapchat', 'Also introduced Snapkidz under', '13 years']
# ['Snapchat', 'Also introduced', 'Snapkidz']
# ['Snapchat', 'Also introduced', 'Snapkidz for users']
# ['Snapchat', 'introduced', 'Snapkidz']
# ['Snapchat', 'introduced', 'Snapkidz for users']
# ['Snapchat', 'introduced Snapkidz in', 'June 2013']
# ['Snapchat', 'According to', 'published statistics']
# ['Snapchat', 'had hit', '10 billion daily video views']
# ['Snapchat', 'had hit', '10 billion video views']
# ['Snapchat', 'suggesting', 'strong investor interest']
# ['Snapchat', 'suggesting', 'investor interest']
# ['Snapchat', 'raised', '$ 1.81 billion in equity offering']
# ['Snapchat', 'suggesting', 'investor interest in company']
# ['Snapchat', 'raised', '$ 1.81 billion']
# ['Snapchat', 'suggesting', 'strong investor interest in company']
# ['Snapchat', 'had', '160 million daily users']
# ['Snapchat', 'had', '160 million daily users growing to 166 million in May']
# ['Snapchat', 'had', '160 million daily users growing']
# ['Snapchat', 'had', '160 million daily active users growing to 166 million']
# ['Snapchat', 'had', '160 million active users']
# ['Snapchat', 'had', '160 million active users growing']
# ['Snapchat', 'had', '160 million daily active users growing in May']
# ['Snapchat', 'had', '160 million daily users growing to 166 million']
# ['Snapchat', 'had', '160 million daily active users']
# ['Snapchat', 'had', '160 million daily active users growing to 166 million in May']
# ['Snapchat', 'had', '160 million active users growing to 166 million']
# ['Snapchat', 'had', '160 million users growing to 166 million in May']
# ['Snapchat', 'had', '160 million daily active users growing']
# ['Snapchat', 'had', '160 million users growing in May']
# ['Snapchat', 'had', '160 million active users growing in May']
# ['Snapchat', 'had', '160 million daily users growing in May']
# ['Snapchat', 'had', '160 million users growing to 166 million']
# ['Snapchat', 'had', '160 million users']
# ['Snapchat', 'had', '160 million active users growing to 166 million in May']
# ['Snapchat', 'had', '160 million users growing']
# ['Snapchat', 'creating', 'multimedia messages referred']
# ['Snapchat', 'creating', 'multimedia messages']
# ['Snapchat', 'uses marketing concepts According to', 'CIO']
# ['Snapchat', 'uses', 'marketing concepts']
# ['Snapchat', 'uses', 'real-time marketing concepts']
# ['Snapchat', 'attracts interest According to', 'Marketing Pro']
# ['Snapchat', 'attracts', 'interest']
# ['Snapchat', 'combining', 'AIDA model with modern technology']
# ['Snapchat', 'combining', 'AIDA model with digital technology']
# ['Snapchat', 'combining', 'AIDA model with modern digital technology']
# ['Snapchat', 'combining', 'AIDA model']
# ['Snapchat', 'combining', 'AIDA model with technology']
# ['Snapchat', 'introduced', 'option']
# ['Snapchat', 'introduced option In', 'September 2015']
# ['Snapchat', 'is intended', 'counteract']
# ['Snapchat', 'introduced Snapcash In', 'November 2014']
# ['Snapchat', 'introduced', 'Snapcash']
# ['Snapchat', 'introduced', 'feature known as Memories']
# ['Snapchat', 'introduced', 'optional feature']
# ['Snapchat', 'introduced', 'new feature known as Memories']
# ['Snapchat', 'introduced', 'new feature']
# ['Snapchat', 'introduced', 'new optional feature known as Memories']
# ['Snapchat', 'introduced feature In', 'July 2016']
# ['Snapchat', 'introduced', 'feature']
# ['Snapchat', 'introduced', 'new optional feature']
# ['Snapchat', 'introduced', 'feature known']
# ['Snapchat', 'introduced', 'new optional feature known']
# ['Snapchat', 'introduced', 'optional feature known as Memories']
# ['Snapchat', 'introduced', 'new feature known']
# ['Snapchat', 'introduced', 'optional feature known']
# ['Snapchat', 'enabling', 'them']
# ['Snapchat', 'allowing', 'users']
# ['Snapchat', 'also launched', 'integration with Twitch including in-stream widget for Snapcodes']
# ['Snapchat', 'launched', 'integration']
# ['Snapchat', 'launched', 'integration with Twitch including in-stream widget']
# ['Snapchat', 'launched', 'integration with Twitch including in-stream widget for Snapcodes']
# ['Snapchat', 'launched', 'integration with Twitch']
# ['Snapchat', 'also launched', 'integration with Twitch including widget for Snapcodes']
# ['Snapchat', 'also launched', 'integration with Twitch including in-stream widget']
# ['Snapchat', 'launched', 'integration with Twitch including widget for Snapcodes']
# ['Snapchat', 'also launched', 'integration']
# ['Snapchat', 'also launched', 'integration with Twitch']
# ['Snapchat', 'launched', 'integration with Twitch including widget']
# ['Snapchat', 'also launched', 'integration with Twitch including widget']
# ['Snapchat', 'emphasize', 'events']
# ['Snapchat', 'emphasize', 'public events']
# ['Twitter', 'to', 'Verified account program']
# ['Snapchat', 'revamped', 'its design']
# ['Snapchat', 'adding', 'search functionality']
# ['Snapchat', 'introduced', 'Custom Stories']
# ['Snapchat', 'introduced Custom Stories In', 'May 2017']
# ['Snapchat', 'through', 'Stories format']
# ['Snapchat', 'major revision of', 'messaging functionality known']
# ['Snapchat', 'revision of', 'messaging functionality known']
# ['Snapchat', 'major revision of', 'messaging functionality known as Chat 2.0']
# ['Snapchat', 'revision of', 'messaging functionality known as Chat 2.0']
# ['Snapchat', 'major revision of', 'messaging functionality']
# ['Snapchat', 'revision of', 'messaging functionality']
# ['Snapchat', 'adding', 'stickers']
# ['Snapchat', 'added In', 'June 2018']
# ['Snapchat', 'added', 'feature']
# ['Snapchat', 'added feature In', 'June 2018']
# ['Snapchat', 'is used for', 'variety']
# ['Snapchat', 'represent', 'direction in social media']
# ['Snapchat', 'been', 'has seen']
# ['Snapchat', 'been', 'has often seen with its users']
# ['Snapchat', 'represent', 'new direction in social media']
# ['Snapchat', 'represent', 'new direction in media']
# ['Snapchat', 'represent', 'direction']
# ['Snapchat', 'been', 'has seen with its users']
# ['Snapchat', 'represent', 'direction in media']
# ['Snapchat', 'been', 'has often seen']
# ['Snapchat', 'represent', 'new direction']
# ['Snapchat', 'put focus With', 'emphasis on accumulation of status']
# ['Snapchat', 'put focus With', 'less emphasis on accumulation']
# ['Snapchat', 'put focus on', 'ephemeral nature of fleeting encounters']
# ['Snapchat', 'put focus With', 'less emphasis on accumulation of ongoing status']
# ['Snapchat', 'put focus on', 'ephemeral nature of encounters']
# ['Snapchat', 'put focus With', 'emphasis on accumulation']
# ['Snapchat', 'put focus With', 'emphasis']
# ['Snapchat', 'put focus With', 'less emphasis on accumulation of status']
# ['Snapchat', 'put focus on', 'nature']
# ['Snapchat', 'put focus on', 'nature of fleeting encounters']
# ['Snapchat', 'put focus on', 'ephemeral nature']
# ['Snapchat', 'put', 'focus']
# ['Snapchat', 'put focus With', 'emphasis on accumulation of ongoing status']
# ['Snapchat', 'put focus on', 'nature of encounters']
# ['Snapchat', 'put focus With', 'less emphasis']
# ['Snapchat', 'announced', 'its then-upcoming advertising efforts']
# ['Snapchat', 'announced', 'its advertising efforts']
# ['Snapchat', 'began In', 'January 2015']
# ['Snapchat', 'making', 'shift focusing on growth']
# ['Snapchat', 'making', 'shift focusing']
# ['Snapchat', 'making', 'shift']
# ['Snapchat', 'making', 'shift focusing on growth to monetization']
# ['Snapchat', 'announced In', 'June 2015']
# ['Snapchat', 'made', 'push']
# ['Snapchat', 'launching feature in', '2014']
# ['Snapchat', 'initially launching feature in', '2014']
# ['Snapchat', 'launching', 'feature']
# ['Snapchat', 'initially launching', 'feature']
# ['Snapchat', 'are', 'watched']
# ['Snapchat', 'are watched in', 'their entirety nine times more than landscape video ads']
# ['Snapchat', 'are watched in', 'their entirety']
# ['Snapchat', 'are watched in', 'their entirety more than landscape video ads']
# ['Snapchat', 'is in', 'United States']
# ['Snapchat', 'released', 'its first hardware product']
# ['Snapchat', 'released', 'first hardware product']
# ['Evan Spiegel', 'CEO of', 'Snap Inc.']
# ['Evan Spiegel', 'called', 'it toy']
# ['Evan Spiegel', 'saw', 'it']
# ['Snapchat', 'Also introduced', 'Snap']
# ['Snapchat', 'introduced', 'Snap']
# ['Snapchat', 'introduced', 'Snap to Store']
# ['Snapchat', 'Also introduced', 'Snap to Store']
# ['Snapchat', 'announced', 'launch']
# ['Snapchat', 'announced launch On', 'November 13 2018']
# ['Snapchat', 'announced development platform In', 'June 2018']
# ['Snapchat', 'announced', 'development platform']
# ['Snapchat', 'announced', 'new third-party development platform known']
# ['Snapchat', 'announced', 'third-party development platform']
# ['Snapchat', 'announced', 'development platform known']
# ['Snapchat', 'announced', 'new development platform known']
# ['Snapchat', 'announced', 'third-party development platform known']
# ['Snapchat', 'announced', 'new third-party development platform']
# ['Snapchat', 'announced', 'new development platform']
# ['Snapchat', 'is increasingly becoming', 'integral part']
# ['Snapchat', 'part of', 'porn industry']
# ['Snapchat', 'is becoming', 'integral part of porn industry']
# ['Snapchat', 'integral part of', 'porn industry']
# ['Snapchat', 'is becoming', 'integral part of online porn industry']
# ['Snapchat', 'part of', 'online porn industry']
# ['Snapchat', 'is increasingly becoming', 'part of online porn industry']
# ['Snapchat', 'is becoming', 'part of online porn industry']
# ['Snapchat', 'is increasingly becoming', 'integral part of online porn industry']
# ['Snapchat', 'is becoming', 'part']
# ['Snapchat', 'is increasingly becoming', 'integral part of porn industry']
# ['Snapchat', 'is becoming', 'integral part']
# ['Snapchat', 'is increasingly becoming', 'part']
# ['Snapchat', 'is increasingly becoming', 'part of porn industry']
# ['Snapchat', 'integral part of', 'online porn industry']
# ['Snapchat', 'is becoming', 'part of porn industry']
# ['Snapchat', 'was hacked on', 'December 31 2013']
# ['Snapchat', 'announced On', 'December 27']
# ['Snapchat', 'apologized after', 'hack']
# ['Snapchat', 'apologized at_time', 'week']
# ['Snapchat', 'settled complaint In', '2014']
# ['Snapchat', 'settled In', '2014']
# ['Snapchat', 'settled', 'complaint made by Federal Trade Commission']
# ['Snapchat', 'settled', 'complaint made']
# ['Snapchat', 'settled', 'complaint']
# ['Snapchat', 'was sued by', 'company']
# ['Snapchat', 'was sued by', 'Canadian company']
# ['Snapchat', 'was sued for', 'infringement on its geofiltering patent']
# ['Snapchat', 'was sued for', 'infringement']
# ['Snapchat', 'was sued In', '2016']
# ['Snapchat', 'called In', 'response']
# ['Snapchat', 'called', 'ridiculous']
# ['Snapchat', 'called In', 'response to allegation']
# ['Snapchat', 'is for', 'everyone']
# ['Snapchat', 'been', 'increase']
# ['Snapchat', 'been increase in', 'advertising on Snapchat']
# ['Snapchat', 'been increase in', 'advertising']
# ['Snapchat', 'was insensitive to', 'violence victims']
# ['Snapchat', 'was insensitive to', 'domestic violence victims']
# ['Snapchat', 'urged', 'fans']

# %%
snap_entities = [
    ['Snapchat', 'raised', '$1.81 billion'],
    ['Snapchat', 'founded', ['Snapkidz', 'Snapcash']],
    ['Snapchat', 'methods', ['AIDA model']],
    ['Snapchat', 'partners', ['Twitch']]
]

# %% [markdown]
# ### Instagram

# %%
company = 'Instagram'
with open(f'{company}.json') as fh:
    data = json.load(fh)
    
text = (re.sub('\[\d+\]', '', data['text'].strip()))
with open(f'{company}.txt', 'w') as fh:
    fh.write(text)

# %%
# !rm instagram_triples.txt
# !python Stanford-OpenIE-Python/main.py -f ../instagram.txt > instagram_triples.txt
# Out:
# rm: instagram_triples.txt: No such file or directory

# %%
with open(f'{company}_triples.txt') as fh:
    triples_raw = fh.read()
    
gen_triples(triples_raw)
# Out:
# ['Instagram', 'rapidly gained popularity with', 'one million users in two months']
# ['Instagram', 'gained popularity with', 'one million users']
# ['Instagram', 'gained popularity After', 'its launch']
# ['Instagram', 'gained', 'popularity']
# ['Instagram', 'rapidly gained popularity with', 'one million registered users in two months']
# ['Instagram', 'gained popularity with', 'one million users in two months']
# ['Instagram', 'gained popularity After', 'its launch in 2010']
# ['Instagram', 'rapidly gained popularity with', 'one million users']
# ['Instagram', 'gained popularity with', 'one million registered users in two months']
# ['Instagram', 'rapidly gained', 'popularity']
# ['Instagram', 'rapidly gained popularity After', 'its launch']
# ['Instagram', 'gained popularity with', 'one million registered users']
# ['Instagram', 'rapidly gained popularity After', 'its launch in 2010']
# ['Instagram', 'rapidly gained popularity with', 'one million registered users']
# ['Facebook', 'acquired service In', 'April 2012']
# ['Facebook', 'acquired service for', 'approximately US$ 1 billion in cash']
# ['Facebook', 'acquired service for', 'US$ 1 billion in cash']
# ['Facebook', 'acquired service for', 'US$ 1 billion']
# ['Facebook', 'acquired service for', 'approximately US$ 1 billion']
# ['Facebook', 'acquired', 'service']
# ['Instagram', 'praised for', 'its influence']
# ['Instagram', 'allegations of', 'censorship']
# ['Instagram', 'through', 'X-PRO2 filter']
# ['Instagram', 'in', 'Series B fundraising round']
# ['Instagram', 'was released for', 'Android phones']
# ['Instagram', 'was released On', 'April 3']
# ['Facebook', 'of', 'cash-on-hand']
# ['Facebook', 'to', 'scheduled IPO']
# ['Facebook', 'was committed in', 'contrast to its past practices']
# ['Facebook', 'was committed to', 'building']
# ['Facebook', 'was committed in', 'contrast']
# ['Facebook', 'was committed independently in', 'contrast to its past practices']
# ['Facebook', 'was committed independently in', 'contrast']
# ['Facebook', 'was committed independently to', 'building']
# ['Instagram', 'launched website profiles In', 'November 2012']
# ['Instagram', 'allowing', 'anyone']
# ['Instagram', 'allowing', 'see']
# ['Instagram', 'launched', 'website profiles']
# ['Instagram', 'upgraded app to', 'Windows']
# ['Instagram', 'upgraded', 'app']
# ['Instagram', 'upgraded app In', 'April 2016']
# ['Instagram', 'of', '600 million users']
# ['Instagram', 'started', 'testing']
# ['Instagram', 'started In', 'March 2014']
# ['Instagram', 'of', 'mobile website']
# ['Instagram', 'revamped', 'its design']
# ['Instagram', 'applied restrictions On', 'June 1']
# ['Instagram', 'applied', 'restrictions']
# ['Instagram', 'applied', 'new restrictions']
# ['Instagram', 'following', 'March announcement']
# ['Instagram', 'introduced On', 'December 6']
# ['Instagram', 'added text On', 'November 28']
# ['Instagram', 'added On', 'November 28']
# ['Instagram', 'added', 'alternative text']
# ['Instagram', 'added', 'text']
# ['Instagram', 'was updated In', 'October 2019']
# ['Instagram', 'introduced', 'hashtags']
# ['Instagram', 'introduced hashtags In', 'January 2011']
# ['Instagram', 'encourages', 'users']
# ['Instagram', 'dropping', 'previous requirement of square frame']
# ['Instagram', 'started In', 'August 2015']
# ['Instagram', 'dropping', 'requirement']
# ['Instagram', 'dropping', 'requirement of frame']
# ['Instagram', 'dropping', 'previous requirement of frame']
# ['Instagram', 'allowing', 'users']
# ['Instagram', 'dropping', 'requirement of square frame']
# ['Instagram', 'started', 'allowing']
# ['Instagram', 'dropping', 'previous requirement']
# ['Instagram', 'added In', 'August 2016']
# ['Instagram', 'removed In', 'September 2016']
# ['Instagram', 'introduced feature In', 'December 2016']
# ['Instagram', 'introduced', 'feature letting']
# ['Instagram', 'introduced', 'feature']
# ['Instagram', 'announced In', 'February 2017']
# ['Instagram', 'updated', 'its website']
# ['Instagram', 'updated', 'its mobile website']
# ['Instagram', 'updated In', 'May']
# ['Instagram', 'allow', 'users']
# ['Instagram', 'Later added Archive feature in', 'May']
# ['Instagram', 'added Archive feature in', 'May']
# ['Instagram', 'Later added in', 'May']
# ['Instagram', 'added in', 'May']
# ['Instagram', 'Later added', 'Archive feature']
# ['Instagram', 'added', 'Archive feature letting']
# ['Instagram', 'Later added', 'Archive feature letting']
# ['Instagram', 'added', 'Archive feature']
# ['Instagram', 'announced', 'letting']
# ['Instagram', 'announced In', 'August']
# ['Instagram', 'launched', 'its version of portrait mode called']
# ['Instagram', 'launched', 'its version']
# ['Instagram', 'launched', 'its version of portrait mode']
# ['Instagram', 'introduced', 'Explore']
# ['Instagram', 'added', 'Videos You Might']
# ['Instagram', 'added Videos You Might In', 'April 2016']
# ['Instagram', 'added to', 'tab']
# ['Instagram', 'added In', 'April 2016']
# ['Instagram', 'added', 'Videos You Might Like channel']
# ['Instagram', 'added Videos You Might to', 'tab']
# ['Instagram', 'once again updated Explore tab In', 'May 2017']
# ['Instagram', 'promote', 'public Stories content from nearby places']
# ['Instagram', 'promote', 'Stories content from nearby places']
# ['Instagram', 'once updated', 'Explore tab']
# ['Instagram', 'again updated In', 'May 2017']
# ['Instagram', 'promote', 'Stories content from places']
# ['Instagram', 'again updated', 'Explore tab']
# ['Instagram', 'once again updated', 'Explore tab']
# ['Instagram', 'updated In', 'May 2017']
# ['Instagram', 'promote', 'public Stories content from places']
# ['Instagram', 'again updated Explore tab In', 'May 2017']
# ['Instagram', 'once updated In', 'May 2017']
# ['Instagram', 'updated', 'Explore tab']
# ['Instagram', 'once updated Explore tab In', 'May 2017']
# ['Instagram', 'promote', 'public Stories content']
# ['Instagram', 'once again updated In', 'May 2017']
# ['Instagram', 'updated Explore tab In', 'May 2017']
# ['Instagram', 'promote', 'Stories content']
# ['Instagram', 'added In', 'February 2012']
# ['Instagram', 'added', 'effect that']
# ['Instagram', 'added Lux filter In', 'February 2012']
# ['Instagram', 'added', 'effect']
# ['Instagram', 'added', 'Lux filter']
# ['Instagram', 'incorporated video sharing in', 'June 2013']
# ['Instagram', 'incorporated', 'video sharing']
# ['Instagram', 'incorporated', '15-second video sharing']
# ['Facebook', 'as', 'attempt competing with then-popular video-sharing application Vine']
# ['Instagram', 'added', 'support']
# ['Instagram', 'added In', 'August 2015']
# ['Instagram', 'added', 'support for widescreen videos']
# ['Instagram', 'added support In', 'August 2015']
# ['Instagram', 'increased', '15-second video limit']
# ['Instagram', 'increased video limit In', 'March 2016']
# ['Instagram', 'increased video limit to', '60 seconds']
# ['Instagram', 'increased', 'video limit']
# ['Instagram', 'announced', 'Instagram Direct']
# ['Instagram', 'announced Instagram Direct In', 'December 2013']
# ['Instagram', 'redesigned In', 'April 2017']
# ['Instagram', 'redesigned', 'permanent into message threads']
# ['Instagram', 'redesigned', 'Direct']
# ['Instagram', 'redesigned', 'permanent into same message threads']
# ['Instagram', 'redesigned', 'permanent']
# ['Instagram', 'added', 'support']
# ['Instagram', 'also added', 'support']
# ['Instagram', 'made', 'it possible']
# ['Instagram', 'launched', 'Instagram Stories']
# ['Instagram', 'launched Instagram Stories In', 'August 2016']
# ['Instagram', 'added with', 'video disappearing immediately']
# ['Instagram', 'added with', 'video disappearing']
# ['Instagram', 'added video functionality with', 'video']
# ['Instagram', 'added video functionality with', 'video disappearing immediately']
# ['Instagram', 'added video functionality to', 'Instagram Stories']
# ['Instagram', 'added', 'allowing']
# ['Instagram', 'added video functionality with', 'video disappearing']
# ['Instagram', 'added video functionality In', 'November']
# ['Instagram', 'added to', 'Instagram Stories']
# ['Instagram', 'added with', 'video']
# ['Instagram', 'added In', 'November']
# ['Instagram', 'added', 'video functionality']
# ['Instagram', 'added', 'live video functionality']
# ['Snapchat', 'of', 'functionality']
# ['Instagram', 'expanded reality sticker feature In', 'May 2017']
# ['Instagram', 'expanded', 'reality sticker feature']
# ['Instagram', 'expanded', 'augmented reality sticker feature']
# ['Instagram', 'revised', 'its live-video functionality']
# ['Instagram', 'revised', 'its functionality']
# ['Instagram', 'allow', 'users']
# ['Instagram', 'allowing', 'respond']
# ['Instagram', 'allowing', 'users']
# ['Instagram', 'started In', 'July']
# ['Instagram', 'started', 'allowing']
# ['Instagram', 'allowing', 'respond to Stories content']
# ['Instagram', 'introduced', 'Story Highlights also known']
# ['Instagram', 'introduced', 'Story Highlights known']
# ['Instagram', 'introduced Story Highlights On', 'December 5']
# ['Instagram', 'introduced', 'Story Highlights']
# ['Instagram', 'had', 'filters']
# ['Instagram', 'join', 'Snapchat']
# ['Instagram', 'as', 'Global Head of Business']
# ['Instagram', 'began', 'its monetization efforts']
# ['Instagram', 'announced', 'then-upcoming rollout of ads in United Kingdom']
# ['Instagram', 'announced', 'rollout of ads']
# ['Instagram', 'announced', 'then-upcoming rollout of ads']
# ['Instagram', 'announced', 'rollout']
# ['Instagram', 'announced', 'rollout of ads in United Kingdom']
# ['Instagram', 'announced rollout In', 'June 2014']
# ['Instagram', 'announced', 'then-upcoming rollout']
# ['Instagram', 'from', 'launch in U.S.']
# ['Instagram', 'buy', 'carousel ads']
# ['Instagram', 'buy carousel ads at_time', 'October']
# ['Instagram', 'buy carousel ads at_time', 'following October']
# ['Instagram', 'announced', 'launch of tools for business accounts including business profiles']
# ['Instagram', 'announced', 'launch of tools including business profiles']
# ['Instagram', 'announced', 'launch of new tools for business accounts']
# ['Instagram', 'announced', 'launch of tools for business accounts']
# ['Instagram', 'announced launch In', 'May 2016']
# ['Instagram', 'announced', 'launch of new tools']
# ['Instagram', 'announced', 'launch of tools']
# ['Instagram', 'announced', 'launch of new tools including new business profiles']
# ['Instagram', 'announced', 'launch of tools including new business profiles']
# ['Instagram', 'announced', 'launch of new tools for business accounts including new business profiles']
# ['Instagram', 'announced', 'launch of new tools for business accounts including business profiles']
# ['Instagram', 'announced', 'launch']
# ['Instagram', 'announced', 'launch of tools for business accounts including new business profiles']
# ['Instagram', 'announced', 'launch of new tools including business profiles']
# ['Instagram', 'announced In', 'February 2016']
# ['Instagram', 'released', 'three apps with functionality']
# ['Instagram', 'released', 'three stand-alone apps with specialized functionality']
# ['Instagram', 'released', 'three apps with specialized functionality']
# ['Instagram', 'released', 'three apps']
# ['Instagram', 'released', 'three stand-alone apps with functionality']
# ['Instagram', 'released', 'three stand-alone apps']
# ['Instagram', 'had', 'one million users']
# ['Instagram', 'had', 'one million registered users']
# ['Instagram', 'had', 'one million registered users in December 2010']
# ['Instagram', 'had', 'one million users in December 2010']
# ['Instagram', 'passed In', 'June 2011']
# ['Instagram', 'was listed among', "Time 's 50 Android Applications"]
# ['Instagram', 'was listed among', "Time 's 50 Best Android Applications"]
# ['Instagram', 'attract generation with', '90 % of 150 million users']
# ['Instagram', 'attract generation under', 'age of 35']
# ['Instagram', 'attract', 'generation']
# ['Instagram', 'attract', 'younger generation']
# ['Instagram', 'attract generation with', '90 %']
# ['Instagram', 'attract generation under', 'age']
# ['Instagram', 'doubled', 'their number of users']
# ['Instagram', 'doubled', 'their number']
# ['Instagram', 'approximately doubled', 'their number of users']
# ['Instagram', 'approximately doubled', 'their number']
# ['Instagram', 'announced In', 'October 2019']
# ['Instagram', "'s head is", 'Vishal Shah']
# ['Instagram', 'announced', 'change to its Terms']
# ['Instagram', 'announced', 'change']
# ['Instagram', 'announced', 'change to its Terms of Service policy']
# ['Instagram', 'announced On', 'December 20']
# ['Instagram', 'deleted', 'account']
# ['Instagram', 'deleted account In', 'October 2013']
# ['Instagram', 'deleted', 'account of photographer Petra Collins']
# ['Instagram', 'deleted', 'account of Canadian photographer Petra Collins']
# ['Instagram', 'began In', 'April 2016']
# ['Instagram', 'has made efforts In', 'response to comments']
# ['Instagram', 'has made efforts In', 'response']
# ['Instagram', 'has made efforts In', "response to abusive comments on users ' photos"]
# ['Instagram', 'has made efforts In', "response to comments on users ' photos"]
# ['Instagram', 'has made efforts In', 'response to abusive comments']
# ['Instagram', 'has made', 'efforts']
# ['Instagram', 'announced In', 'June 2017']
# ['Instagram', 'stated In', 'response to survey']
# ['Instagram', 'stated In', 'response']
# ['Instagram', 'began', 'testing in Canada']
# ['Instagram', 'testing in', 'Canada']
# ['Instagram', 'began', 'testing']
# ['Instagram', 'began In', 'May 2019']
# ['Instagram', 'begun', 'efforts']
# ['Instagram', 'wrote In', 'now-deleted Facebook post']
# ['Instagram', 'wrote In', 'Facebook post']
# ['Facebook', 'was under', 'scrutiny']
# ['Facebook', 'was under', 'scrutiny for its algorithms used']
# ['Facebook', 'was under', 'at time parent company scrutiny for its algorithms']
# ['Facebook', 'was under', 'at time parent company scrutiny for its algorithms used for offensive purposes']
# ['Facebook', 'was under', 'scrutiny for its algorithms used for purposes']
# ['Facebook', 'was under', 'at same time parent company scrutiny for its algorithms used for offensive purposes']
# ['Facebook', 'was under', 'at time parent company scrutiny for its algorithms used']
# ['Facebook', 'was under', 'at same time parent company scrutiny']
# ['Facebook', 'was under', 'at same time parent company scrutiny for its algorithms']
# ['Facebook', 'was under', 'at same time parent company scrutiny for its algorithms used for purposes']
# ['Facebook', 'was under', 'scrutiny for its algorithms']
# ['Facebook', 'was under', 'at time parent company scrutiny']
# ['Facebook', 'was under', 'at same time parent company scrutiny for its algorithms used']
# ['Facebook', 'was under', 'scrutiny for its algorithms used for offensive purposes']
# ['Facebook', 'was under', 'at time parent company scrutiny for its algorithms used for purposes']
# ['Instagram', 'in', 'developer tools']
# ['Instagram', 'caused', 'userbase']
# ['Instagram', 'caused userbase with', 'December 2018 update']
# ['Instagram', 'prevent', 'photos']
# ['Instagram', 'prevent', 'photos of incident']
# ['Instagram', 'was runner-up for', 'Best Mobile App']
# ['Instagram', 'was runner-up for', 'Mobile App']
# ['Instagram', 'was runner-up for', 'Mobile App in January 2011']
# ['Instagram', 'was runner-up for', 'Best Mobile App at 2010 TechCrunch Crunchies in January 2011']
# ['Instagram', 'was runner-up for', 'Best Mobile App at 2010 TechCrunch Crunchies']
# ['Instagram', 'was runner-up for', 'Mobile App at 2010 TechCrunch Crunchies in January 2011']
# ['Instagram', 'was runner-up for', 'Best Mobile App in January 2011']
# ['Instagram', 'was runner-up for', 'Mobile App at 2010 TechCrunch Crunchies']
# ['Instagram', 'won App in', 'SF Weekly Web Awards']
# ['Instagram', 'won App in', 'SF Weekly Web Awards in September 2011']
# ['Instagram', 'won', 'Made App']
# ['Instagram', 'won', 'App']
# ['Instagram', 'won', 'Best Made App']
# ['Instagram', 'won', 'Locally Made App']
# ['Instagram', 'won', 'Best Locally Made App']
# ['Instagram', 'won', 'Best App']
# ['Instagram', 'was named', 'No. 1']

# %%
ig_entities = [
    ['Instagram', 'launched', ['Videos You Might Like channel', 'Instagram Stories', 
                               'Story Highlights', 'Instagram Direct']],
    ['Instagram', 'won', ['Best Locally Made App']]
]

# %% [markdown]
# ### Periscope

# %%
company = 'Periscope'
with open(f'{company}.json') as fh:
    data = json.load(fh)
    
text = (re.sub('\[\d+\]', '', data['text'].strip()))
with open(f'{company}.txt', 'w') as fh:
    fh.write(text)

# %%
# !rm periscope_triples.txt
# !python Stanford-OpenIE-Python/main.py -f ../periscope.txt > periscope_triples.txt
# Out:
# rm: periscope_triples.txt: No such file or directory

# %%
with open(f'{company}_triples.txt') as fh:
    triples_raw = fh.read()
    
gen_triples(triples_raw, filter_flag=False)
# Out:
# ['Periscope', 'is', 'live video streaming app for Android']
# ['Periscope', 'is', 'video streaming app for Android']
# ['Periscope', 'acquired by', 'Twitter']
# ['Periscope', 'is', 'video streaming app']
# ['Periscope', 'is', 'live']
# ['Periscope', 'is', 'live video streaming app for Android developed by Kayvon Beykpour']
# ['Periscope', 'is', 'video streaming app for Android developed by Kayvon Beykpour']
# ['Periscope', 'is', 'live video streaming app']
# ['Periscope', 'is', 'video streaming app for Android developed']
# ['Periscope', 'acquired before', 'launch']
# ['Periscope', 'is', 'live video streaming app for Android developed']
# ['Periscope', 'acquired before', 'launch in 2015']
# ['launch', 'is in', '2015']
# ['Contents Beykpour', 'came', 'Bernstein']
# ['Contents Beykpour', 'traveling', 'Bernstein']
# ['Contents Beykpour', 'traveling abroad', 'Bernstein']
# ['Contents Beykpour', 'traveling abroad in', '2013']
# ['Contents Beykpour', 'traveling in', '2013']
# ['He', 'wanted', 'see']
# ['he', 'turned to', 'Twitter']
# ['he', 'could read about', 'protests']
# ['They', 'started company in', 'February 2014']
# ['They', 'started', 'company']
# ['They', 'started company under', 'name Bounty']
# ['Stanford StartX', 'is in', 'April 2014']
# ['They', 'raised', '$ 1.5 million']
# ['Periscope', 'was acquired at_time', 'January 2015']
# ['product', 'had', 'had launched']
# ['product', 'had', 'had publicly launched']
# ['Periscope', 'was acquired by', 'Twitter']
# ['Periscope', 'was', 'acquired January 2015 by Twitter']
# ['Periscope', 'was', 'acquired']
# ['acquisition', 'was announced in', 'tweet']
# ['acquisition', 'was', 'officially announced']
# ['acquisition', 'was officially announced in', 'tweet']
# ['video streaming app Meerkat', 'was', 'breakout hit at South']
# ['acquisition', 'was', 'announced']
# ['rival video streaming app Meerkat', 'was', 'breakout hit']
# ['video streaming app Meerkat', 'was', 'breakout hit']
# ['acquisition', 'was announced in', 'tweet from Periscope']
# ['rival video streaming app Meerkat', 'was', 'breakout hit at South']
# ['acquisition', 'was officially announced in', 'tweet from Periscope']
# ['Meerkat', 'became', 'talk of SXSW due']
# ['Meerkat', 'became', 'talk due']
# ['Meerkat', 'became', 'talk of SXSW partially due']
# ['Meerkat', 'became', 'talk partially due']
# ['Periscope', 'was', 'launched']
# ['Periscope', 'was launched on', '26 March 2015']
# ['Periscope', 'was', 'on 26 May 2015 released for Android']
# ['Periscope', 'was released for', 'Android']
# ['Periscope', 'Later was released on', '26 May 2015']
# ['Periscope', 'was', 'Later released']
# ['Periscope', 'was released on', '26 May 2015']
# ['Periscope', 'Later was released for', 'Android']
# ['Periscope', 'was', 'released']
# ['Periscope', 'was', 'Later on 26 May 2015 released for Android']
# ['Periscope', 'announced On', '12 August 2015']
# ['it', 'was', 'launched']
# ['it', 'surpassed', '10 million accounts']
# ['amount', 'reached', 'level of 40 years']
# ['company', 'noted At', 'same time']
# ['level', 'amount of', 'video']
# ['company', 'noted At', 'time']
# ['amount', 'reached', 'level']
# ['amount', 'reached', 'level of 40 years per day']
# ['Apple', 'named', 'Periscope']
# ['Apple', 'named Periscope On', '9 December 2015']
# ['Apple', 'named Periscope as', 'iPhone App']
# ['Apple', 'named Periscope as', 'iPhone App of Year']
# ['that', 'allows', 'users']
# ['that', 'allows users to', 'stream']
# ['that', 'allows users to', 'stream live from GoPro']
# ['that', 'allows users to', 'stream live']
# ['some', 'were', 'In December 2016 integrated into Twitter app']
# ['some', 'were', 'In December 2016 integrated into main Twitter app']
# ['some', 'were integrated into', 'main Twitter app']
# ['some', 'were', 'integrated']
# ['some', 'were integrated In', 'December 2016']
# ['Periscope', 'of', 'features']
# ['some', 'were integrated into', 'Twitter app']
# ['wider partnership', 'is with', 'Twitter to stream']
# ['Democratic members', 'staged sit-in on', 'House floor']
# ['members', 'staged', 'sit-in']
# ['members', 'protest', 'lack of vote']
# ['Democratic members', 'protest', 'lack of vote']
# ['members', 'protest', 'lack of vote on gun control bill']
# ['Democratic members', 'staged sit-in In', 'June 2016']
# ['members', 'staged sit-in In', 'June 2016']
# ['members', 'protest', 'lack']
# ['Democratic members', 'protest', 'lack']
# ['members', 'staged sit-in on', 'House floor']
# ['Democratic members', 'staged', 'sit-in']
# ['Democratic members', 'protest', 'lack of vote on gun control bill']
# ['C-SPAN', 'However was able after', 'brief interruption']
# ['C-SPAN', 'was', 'However able']
# ['Rep. Scott Peters', 'streamed', 'activity']
# ['Rep. Scott Peters speakers', 'using', 'his Periscope account']
# ['C-SPAN', 'was', 'able']
# ['C-SPAN', 'broadcast', 'sit-in']
# ['C-SPAN', 'was able after', 'interruption']
# ['C-SPAN', 'was able after', 'brief interruption']
# ['C-SPAN', 'However was able after', 'interruption']
# ['Turkish court', 'prevent', 'scandal']
# ['Turkish court', 'banned', 'Periscope']
# ['court', 'banned Periscope in', 'Turkey']
# ['court', 'prevent', 'scandal']
# ['court', 'banned', 'Periscope']
# ['Turkish court', 'banned Periscope in', 'Turkey']
# ['Periskop', 'has', 'similar name']
# ['Periskop', 'has', 'name']
# ['Turkish court', 'banned Periscope On', '12 June 2018']
# ['court', 'banned Periscope On', '12 June 2018']
# ['services', 'are available in', 'mobile application']
# ['services', 'are available in', 'application']
# ['services', 'are', 'available']
# ['Users', 'are', 'able']
# ['it', 'broadcast through', 'Periscope']
# ['it', 'is', 'possible']
# ['it', 'is', 'also possible']
# ['viewers', 'send hearts to', 'broadcaster']
# ['viewers', 'send', 'hearts']
# ['Periscope', 'allows', 'viewers']
# ['user', 'can follow', 'that']
# ['users', 'blocked by', 'scoper']
# ['users', 'are', 'added']
# ['users', 'are added to', 'blocked list']
# ['users', 'are added to', 'list']
# ['scopers', 'block', 'user']
# ['they', 'are blocked from', 'scope']
# ['enough scopers', 'block', 'user']
# ['they', 'are', 'blocked']
# ['user', 'gets', 'shadowbanned']
# ['citation', 'needed On', '8 September 2015']
# ['Periscope', 'building', 'Apple TV app']
# ['Periscope', 'added', 'ability']
# ['Periscope', 'added ability On', '10 September 2015']
# ['Periscope', 'added On', '10 September 2015']
# ['Periscope', 'added', 'ability broadcast']
# ['several users', 'air', 'fifth-season premiere']
# ['users', 'air', "premiere of HBO 's Game of Thrones"]
# ['users', 'used', 'it']
# ['users', 'air', "fifth-season premiere of HBO 's Game"]
# ['users', 'air', "fifth-season premiere of HBO 's Game of Thrones"]
# ['several users', 'used', 'it']
# ['users', 'air', "premiere of HBO 's Game"]
# ['copyright infringement', 'for misappropriated is', 'issue']
# ['it', 'users of', 'service']
# ['users', 'air', 'fifth-season premiere']
# ['several users', 'air', "fifth-season premiere of HBO 's Game"]
# ['several users', 'air', "premiere of HBO 's Game of Thrones"]
# ['app', 'can', 'can misappropriated for copyright infringement']
# ['app', 'can', 'can misappropriated']
# ['several users', 'air', 'premiere']
# ['app', 'of', 'launch']
# ['it', 'several users of', 'service']
# ['several users', 'air', "fifth-season premiere of HBO 's Game of Thrones"]
# ['HBO', 'of', 'Game of Thrones']
# ['users', 'air', 'premiere']
# ['several users', 'air', "premiere of HBO 's Game"]
# ['better tools', 'deal with', 'content']
# ['service', 'needs', 'tools']
# ['tools', 'deal with', 'copyrighted content']
# ['better tools', 'deal', 'policies']
# ['service', 'needs', 'better tools']
# ['better tools', 'deal with', 'copyrighted content']
# ['tools', 'deal', 'policies']
# ['tools', 'deal with', 'content']
# ['content', 'violates', "Periscope 's terms"]
# ['copyrighted content', 'violates', "Periscope 's terms"]
# ['copyrighted content', 'result in', 'suspension']
# ['copyrighted content', 'violates', "Periscope 's terms of service"]
# ['content', 'violates', "Periscope 's written terms"]
# ['content', 'violates', "Periscope 's written terms of service"]
# ['copyrighted content', 'violates', "Periscope 's written terms"]
# ['copyrighted content', 'violates', "Periscope 's written terms of service"]
# ['Periscope', 'has', 'written terms of service']
# ['content', 'violates', "Periscope 's terms of service"]
# ['content', 'result in', 'suspension']
# ['its pay', 'close eye', 'it believes']
# ['its pay', 'eye', 'it believes']
# ['their broadcasts', 'delete', 'them']
# ['users', 'were', 'able']
# ['users', 'using', 'Katch.me']
# ['users', 'capture', 'their scopes']
# ['It', 'collecting videos on', '22 April 2016']
# ['It', 'collecting', 'videos']
# ['television channel', 'based around', 'Periscope']
# ['television channel', 'is', 'PeriscopeTV']
# ['']

# %%
periscope_entities = [
    ['Periscope (app)', 'launched', ['Apple TV app']]
]

# %% [markdown]
# ### Summify

# %%
company = 'Summify'
with open(f'{company}.json') as fh:
    data = json.load(fh)
    
text = (re.sub('\[\d+\]', '', data['text'].strip()))
with open(f'{company}.txt', 'w') as fh:
    fh.write(text)

# %%
# !rm summify_triples.txt
# !python Stanford-OpenIE-Python/main.py -f ../summify.txt > summify_triples.txt
# Out:
# rm: summify_triples.txt: No such file or directory

# %%
with open(f'{company}_triples.txt') as fh:
    triples_raw = fh.read()
    
gen_triples(triples_raw, filter_flag=False)
# Out:
# ['Summify', 'was', 'social']
# ['Summify', 'was', 'social news aggregator']
# ['Summify', 'was', 'social news aggregator founded']
# ['Summify', 'was', 'news aggregator']
# ['Summify', 'was', 'news aggregator founded by Mircea Paşoi']
# ['Summify', 'was', 'news aggregator founded']
# ['Summify', 'was', 'social news aggregator founded by Mircea Paşoi']
# ['service', 'emails', 'its users']
# ['platform', 'supported', 'Twitter']
# ['Advisors', 'include', 'CEO of Hootsuite']
# ['Advisors', 'include', 'Ryan Holmes']
# ['Advisors', 'include', 'CEO']
# ['Advisors', 'include', 'CEO']
# ['Advisors', 'include', 'CEO of Redbeacon']
# ['Ryan Holmes', 'CEO of', 'Hootsuite']
# ['Ryan Holmes', 'CEO of', 'Redbeacon']
# ['Contents', 'is In', '2009']
# ['Contents', 'created', 'ReadFu']
# ['ReadFu', 'was', 'accepted']
# ['ReadFu', 'was accepted In', 'January 2010']
# ['ReadFu', 'was', 'In January 2010 accepted into Vancouver']
# ['ReadFu', 'was accepted into', 'Vancouver']
# ['service', 'was renamed', 'began']
# ['2010 service', 'was renamed', 'began']
# ['2010 service', 'was', 'renamed']
# ['service', 'was renamed as', 'Summify']
# ['service', 'was', 'renamed']
# ['service', 'was', 'On March 20 renamed as Summify']
# ['2010 service', 'was renamed On', 'March 20']
# ['2010 service', 'was', 'On March 20 renamed as Summify']
# ['2010 service', 'was renamed as', 'Summify']
# ['service', 'was renamed On', 'March 20']
# ['Paşoi', 'announced', 'Strat']
# ['2010 Paşoi', 'announced', 'Strat']
# ['team', 'receiving', 'feedback']
# ['its users', 'enjoyed', 'article']
# ['its users', 'enjoyed', 'short article']
# ['team', 'announced On', 'March 22 2011']
# ['Summify', 'released app on', 'Apple App Store']
# ['Summify', 'released', 'free app']
# ['Summify', 'released', 'app']
# ['Summify', 'released app on', 'Apple App Store July 8 2011']
# ['users', 'consume', 'their web summaries']
# ['app', 'allows', 'users']
# ['users', 'consume', 'their web summaries from iOS devices']
# ['users', 'consume', 'their web summaries from iOS mobile devices']
# ['Summify', 'was', 'acquired']
# ['Summify', 'was', 'acquired by Twitter on January 19 2012']
# ['Summify', 'was acquired by', 'Twitter']
# ['Summify', 'was acquired on', 'January 19 2012']
# ['It', 'been', 'has also featured']
# ['It', 'been', 'has featured']
# ['It', 'been', 'has featured in Time']
# ['It', 'been', 'has also featured in Time']
# ['']

# %%
summify_entities = [
    ['Summify', 'advisors', ['Ryan Holmes']]
]

# %% [markdown]
# ### Combine

# %%
# From other notebook
twitter_entities = [
    ['Twitter', 'created_in', 'March 2006'],
#     ['Jack Dorsey', 'studied_at', 'New York University'], (Duplicate)
    ['Twitter', 'acquired', ['Crashlytics', 'Trendrr', 'SecondSync', 'Bluefin Labs']],
    ['Twitter', 'partners', ['IBM']],
    ['Twitter', 'backers', ['Union Square Ventures', 'Digital Garage', 'Spark Capital']],
    ['Twitter', 'banned_in', ['Iran', 'Egypt']]
]

# %%
all_entities = twitter_entities + fb_entities + vine_entities + snap_entities \
    + ig_entities + periscope_entities + summify_entities

# %%
all_entities
# Out:
# [['Twitter', 'created_in', 'March 2006'],
#  ['Twitter',
#   'acquired',
#   ['Crashlytics', 'Trendrr', 'SecondSync', 'Bluefin Labs']],
#  ['Twitter', 'partners', ['IBM']],
#  ['Twitter',
#   'backers',
#   ['Union Square Ventures', 'Digital Garage', 'Spark Capital']],
#  ['Twitter', 'banned_in', ['Iran', 'Egypt']],
#  ['Facebook', 'acquired', ['Instagram', 'Onavo']],
#  ['Facebook', 'founded', ['Libra Networks', 'Internet.org']],
#  ['Facebook', 'associated_with', ['Cambridge Analytica']],
#  ['Facebook', 'won', ['Crunchie Best Startup']],
#  ['Facebook', 'banned', ['Alex Jones']],
#  ['Facebook', 'breached_data', '50 million'],
#  ['WhatsApp', 'sued', 'Israeli surveillance firm'],
#  ['Vine (service)', 'launched', 'Vine Kids'],
#  ['Vine (service)', 'won', "Time's '50 Android Apps"],
#  ['Snapchat', 'raised', '$1.81 billion'],
#  ['Snapchat', 'founded', ['Snapkidz', 'Snapcash']],
#  ['Snapchat', 'methods', ['AIDA model']],
#  ['Snapchat', 'partners', ['Twitch']],
#  ['Instagram',
#   'launched',
#   ['Videos You Might Like channel',
#    'Instagram Stories',
#    'Story Highlights',
#    'Instagram Direct']],
#  ['Instagram', 'won', ['Best Locally Made App']],
#  ['Periscope (app)', 'launched', ['Apple TV app']],
#  ['Summify', 'advisors', ['Ryan Holmes']]]

# %%
entities = {}
with open('../wiki_crawler/entities.json') as fh:
    for entity in fh.readlines():
        entity_data = json.loads(entity)
        if entity_data['name'] in entities:
            print(entity_data['name'])
        entities[entity_data['name']] = entity_data
# Out:
# Periscope (app)
# Instagram
# Vine (service)
# Facebook
# Twitter
# WeChat
# Reddit
# Snapchat
# Twitter

# %%
for new_e in all_entities:
    source = new_e[0]
    edge = new_e[1]
    if edge == 'acquired':
        edge = 'subsidiaries'
        target = list(set(entities[source]['subsidiaries'] + new_e[2]))
    elif edge == 'founded':
        edge = 'products'
        target = list(set(entities[source].get('products', []) + new_e[2]))
    else:
        target = new_e[2]
    entities[source][edge] = target

# %%
# !rm all_entities.json

# %%
# Update file with all entities
with open('all_entities.json', 'w') as fh:
    for key, entity in entities.items():
        json.dump(entity, fh)
        fh.write('\n')
