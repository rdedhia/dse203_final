# %%
import json
import re
import pandas as pd

# %%
with open('Twitter.json') as fh:
    data = json.load(fh)

# %%
text = (re.sub('\[\d+\]', '', (data['abstract'] + data['text']).strip()))

# %%
entity_df = pd.read_json('../wiki_crawler/entities.json', lines=True)

# %%
entity_names = entity_df['name'].unique()

# %%
entity_names
# Out:
# array(['Facebook', 'Summify', 'Snapchat', 'Periscope (app)',
#        'Vine (service)', 'Instagram', 'Twitter', 'Mike Schroepfer',
#        'Libra (cryptocurrency)', 'Oculus VR', 'WhatsApp',
#        'Sheryl Sandberg', 'Vancouver', 'Menlo Park, California',
#        'Chris Hughes', 'Dustin Moskovitz', 'Evan Spiegel', 'JavaScript',
#        'Scala (programming language)', 'Ruby (programming language)',
#        'Omid Kordestani', 'Java (programming language)',
#        'Evan Williams (Internet entrepreneur)', 'Biz Stone',
#        'Jack Dorsey', 'New York Stock Exchange', 'San Francisco',
#        'Snap Inc.', 'Bobby Murphy (businessman)', 'Eduardo Saverin',
#        'Mark Zuckerberg', 'Cambridge, Massachusetts', 'Nasdaq',
#        'S&P 500 Index', 'S&P 100'], dtype=object)

# %%
with open('twitter.txt', 'w') as fh:
    fh.write(text)

# %%
# !rm twitter_triples.txt
# !python Stanford-OpenIE-Python/main.py -f ../twitter.txt > twitter_triples.txt

# %%
with open('twitter_triples.txt') as fh:
    triples_raw = fh.read()

# %%
def filter_entities(cand):
    # Only consider triples if the source node is in the list of entity names
    if cand[0] not in entity_names:
        return False
    
    # Remove edges and target nodes that are too long    
    if len(cand[1].split()) > 4:
         return False
        
    if len(cand[2].split()) > 8:
        return False
    
    # Remove not useful verbs
    if trip[1] in {'is', 'was', 'has', 'be'}:
        return False
    
    return True

# %%
# Generate all potentially useful triple candidates
for t in triples_raw.split('\n'):
    trip = t.split(', ')
    if filter_entities(trip):
        print(trip)
# Out:
# ['Twitter', 'is based in', 'California']
# ['Twitter', 'is based in', 'San Francisco']
# ['Twitter', 'was created', 'launched in July']
# ['Twitter', 'was created in', 'March 2006']
# ['Twitter', 'launched in', 'July']
# ['Twitter', 'was created', 'launched']
# ['Twitter', 'was created by', 'Jack Dorsey']
# ['Twitter', 'was largest source During', '2016 U.S. election']
# ['Twitter', 'was largest source During', '2016 U.S. presidential election']
# ['Twitter', 'was source During', '2016 U.S. election']
# ['Twitter', 'was source During', '2016 U.S. presidential election']
# ['Jack Dorsey', 'introduced', 'idea']
# ['Jack Dorsey', 'introduced', 'idea of individual']
# ['Jack Dorsey', 'student at', 'New York University']
# ['Biz Stone', 'formed', 'other members']
# ['Biz Stone', 'formed', 'members of Odeo']
# ['Biz Stone', 'formed', 'Dorsey']
# ['Biz Stone', 'formed', 'other members of Odeo']
# ['Biz Stone', 'formed Obvious Corporation In', 'October 2006']
# ['Biz Stone', 'formed', 'Obvious Corporation']
# ['Biz Stone', 'formed', 'Evan Williams']
# ['Biz Stone', 'formed', 'members']
# ['Twitter', 'in', 'startup']
# ['Twitter', 'for', 'popularity']
# ['Twitter', 'moved up to', 'third-highest-ranking social networking site in January 2009']
# ['Twitter', 'moved up to', 'social networking site']
# ['Twitter', 'moved to', 'networking site']
# ['Twitter', 'moved up to', 'third-highest-ranking networking site in January 2009']
# ['Twitter', 'moved from', 'its previous rank']
# ['Twitter', 'moved up from', 'its rank of twenty-second']
# ['Twitter', 'moved to', 'networking site in January 2009']
# ['Twitter', 'moved up from', 'its rank']
# ['Twitter', 'moved from', 'its previous rank of twenty-second']
# ['Twitter', 'moved to', 'social networking site']
# ['Twitter', 'moved up from', 'its previous rank of twenty-second']
# ['Twitter', 'moved to', 'third-highest-ranking networking site in January 2009']
# ['Twitter', 'moved to', 'third-highest-ranking social networking site']
# ['Twitter', 'moved to', 'social networking site in January 2009']
# ['Twitter', 'moved up to', 'networking site in January 2009']
# ['Twitter', 'noted on', 'Compete.com']
# ['Twitter', 'moved to', 'third-highest-ranking social networking site in January 2009']
# ['Twitter', 'moved up from', 'its previous rank']
# ['Twitter', 'moved to', 'third-highest-ranking networking site']
# ['Twitter', 'moved up to', 'third-highest-ranking social networking site']
# ['Twitter', 'moved up to', 'third-highest-ranking networking site']
# ['Twitter', 'moved from', 'its rank of twenty-second']
# ['Twitter', 'moved up to', 'networking site']
# ['Twitter', 'moved from', 'its rank']
# ['Twitter', 'moved up to', 'social networking site in January 2009']
# ['Twitter', 'acquired', 'application developer Atebits']
# ['Twitter', 'tested', 'new homepage']
# ['Twitter', 'tested', 'homepage']
# ['Twitter', 'tested homepage On', 'April 5']
# ['Twitter', 'overhauled more', 'its website']
# ['Twitter', 'overhauled once more', 'its website']
# ['Twitter', 'overhauled', 'its website']
# ['Twitter', 'agreed to', 'partnership']
# ['Twitter', 'agreed', 'Yandex']
# ['Twitter', 'to', 'real time news']
# ['Twitter', 'celebrated', 'its sixth birthday']
# ['Twitter', 'celebrated', 'its birthday']
# ['Twitter', 'announced In', 'April 2012']
# ['Twitter', 'expanded', 'its office']
# ['Twitter', 'expanded', 'its office in Dublin']
# ['Twitter', 'also expanded', 'its office in Dublin']
# ['Twitter', 'also expanded', 'its office']
# ['Twitter', 'acquired', 'video clip company']
# ['Twitter', 'acquired', 'video clip company called']
# ['Twitter', 'released', 'Vine']
# ['Twitter', 'announced On', 'December 18 2012']
# ['Twitter', 'hit', '100 million users']
# ['Twitter', 'hit', '100 million monthly active users']
# ['Twitter', 'hit', '100 million monthly users']
# ['Twitter', 'hit', '100 million active users']
# ['Twitter', 'acquired', 'Crashlytics']
# ['Twitter', 'acquired Crashlytics in', 'order']
# ['Twitter', 'acquired Crashlytics On', 'January 28 2013']
# ['Twitter', 'launched', 'music app called']
# ['Twitter', 'launched', 'music app called for iPhone']
# ['Twitter', 'launched', 'music app']
# ['Twitter', 'launched music app On', 'April 18']
# ['Twitter', 'acquired', 'Trendrr']
# ['Twitter', 'acquired', 'Trendrr followed']
# ['Twitter', 'acquired', 'Trendrr followed by acquisition']
# ['Twitter', 'acquired', 'Trendrr followed by acquisition of MoPub']
# ['Twitter', 'acquired', 'Trendrr followed by acquisition on September 9 2013']
# ['Twitter', 'acquired Trendrr On', 'August 28']
# ['Twitter', 'announced On', 'June 4']
# ['Twitter', 'announced On', 'June 19']
# ['Twitter', 'via', 'Amplify program']
# ['Twitter', 'announced In', 'July 2014']
# ['Twitter', 'announced On', 'July 31']
# ['Twitter', 'announced', 'partnership']
# ['Twitter', 'announced partnership On', 'October 29 2014']
# ['Twitter', 'announced', 'partnership with IBM']
# ['Twitter', 'announced', 'new partnership with IBM']
# ['Twitter', 'announced', 'new partnership']
# ['Twitter', 'announced On', 'February 11 2015']
# ['Twitter', 'announced', 'its acquisition']
# ['Twitter', 'announced', 'its acquisition of Periscope']
# ['Twitter', 'acquired', 'artificial intelligence startup called for $ 150 million']
# ['Twitter', 'acquired', 'artificial intelligence startup']
# ['Twitter', 'acquired', 'artificial intelligence startup called']
# ['Twitter', 'announced On', 'September 12']
# ['Twitter', 'raise', 'US$ 1 billion']
# ['Twitter', 'showing', 'loss of $ 511 million']
# ['Twitter', 'showing', 'net loss of $ 511 million']
# ['Twitter', 'showing loss in', 'fourth quarter']
# ['Twitter', 'published', 'its results']
# ['Twitter', 'showing loss in', 'fourth quarter of 2013']
# ['Twitter', 'showing', 'loss']
# ['Twitter', 'showing', 'net loss']
# ['Twitter', 'published', 'its first results']
# ['Twitter', 'showing loss in', 'quarter of 2013']
# ['Twitter', 'showing loss in', 'quarter']
# ['Twitter', 'revamped', 'its dashboard']
# ['Twitter', 'improve', 'user experience']
# ['Twitter', 'improve', 'new user experience']
# ['Twitter', 'of', 'board of directors']
# ['Twitter', 'is In', '2011']
# ['Twitter', 'is in', 'San Francisco']
# ['Twitter', 'from', 'board of directors']
# ['Twitter', 'announced In', 'October 2012']
# ['Twitter', 'named', 'former Goldman Sachs executive Anthony Noto']
# ['Twitter', 'announced On', 'June 10']
# ['Twitter', 'has become by', 'its signature bird logo']
# ['Twitter', 'has become', 'internationally identifiable']
# ['Twitter', 'has become', 'identifiable']
# ['Twitter', 'Starting at_time', 'today']
# ['Twitter', 'allows', 'users']
# ['Twitter', 'revolves around', 'principle']
# ['Twitter', 'revolves around', 'principle of followers']
# ['Twitter', 'revolves As', 'social network']
# ['Twitter', 'revolves As', 'network']
# ['Jack Dorsey', 'Despite', 'own open contention']
# ['Twitter', 'tweets from', 'platform called']
# ['Twitter', 'tweets from', 'alternative platform']
# ['Twitter', 'only supports', 'tweets from Bharti Airtel']
# ['Twitter', 'supports', 'tweets from Bharti Airtel']
# ['Twitter', 'tweets from', 'Bharti Airtel']
# ['Twitter', 'supports', 'tweets']
# ['Twitter', 'tweets from', 'alternative platform called']
# ['Twitter', 'only supports', 'tweets']
# ['Twitter', 'tweets from', 'platform']
# ['Twitter', 'has used for', 'automatic shortening of URLs']
# ['Twitter', 'has used', 'its own t.co domain']
# ['Twitter', 'has used Since', 'June 2011']
# ['Twitter', 'has used for', 'shortening of URLs']
# ['Twitter', 'within', '140 character limit']
# ['Twitter', 'has used', 'its t.co domain']
# ['Twitter', 'handles Since', 'March 30']
# ['Twitter', 'handles', 'added']
# ['Twitter', 'added to', 'conversation']
# ['Twitter', 'handles', 'added to conversation']
# ['Twitter', 'doubled', 'their 140-character-limitation']
# ['Twitter', 'doubled', 'their historical 140-character-limitation']
# ['Twitter', 'introduced feature On', 'Tuesday']
# ['Twitter', 'introduced', 'feature']
# ['Twitter', 'prevent', 'manipulation with success']
# ['Twitter', 'prevent', 'manipulation with limited success']
# ['Twitter', 'has altered', 'trend algorithm']
# ['Twitter', 'prevent', 'manipulation']
# ['Twitter', 'censored', '#Thatsafrican']
# ['Twitter', 'removed', '#NaMOinHyd']
# ['Twitter', 'removed', '#NaMOinHyd from list']
# ['Twitter', '#NaMOinHyd from', 'trending list']
# ['Twitter', 'added', 'National Congress-sponsored hashtag']
# ['Twitter', 'added', 'Indian National hashtag']
# ['Twitter', 'added', 'Indian National Congress-sponsored hashtag']
# ['Twitter', 'added', 'National hashtag']
# ['Twitter', 'removed', '#NaMOinHyd from trending list']
# ['Twitter', '#NaMOinHyd from', 'list']
# ['Twitter', 'in', 'apps']
# ['Twitter', "'s TweetDeck is", 'Salesforce.com']
# ['Twitter', 'including', 'own TweetDeck']
# ['Twitter', 'launched', "their Verified Accounts ' program"]
# ['Twitter', 'being criticized by', 'Kanye West']
# ['Twitter', 'being', 'criticized']
# ['Twitter', 'stated After', 'beta period']
# ['Twitter', 'stated in', 'their FAQ']
# ['Twitter', 'announced', 'public application process']
# ['Twitter', 'announced', 'application process']
# ['Twitter', 'announced application process In', 'July 2016']
# ['Twitter', 'continued despite', 'his requests']
# ['Twitter', 'deny', 'verification of Julian Assange']
# ['Twitter', 'continued As of', 'November 2017']
# ['Twitter', 'deny', 'verification']
# ['Twitter', 'on', 'Periscope']
# ['Twitter', 'introduced Twitter Lite with', 'size designed']
# ['Twitter', 'introduced', 'web app designed for regions']
# ['Twitter', 'introduced', 'Twitter Lite']
# ['Twitter', 'introduced', 'progressive web app designed']
# ['Twitter', 'introduced', 'web app designed for regions with unreliable']
# ['Twitter', 'introduced Twitter Lite In', 'April 2017']
# ['Twitter', 'introduced', 'web app designed']
# ['Twitter', 'introduced', 'progressive web app']
# ['Twitter', 'introduced', 'progressive web app designed for regions with unreliable']
# ['Twitter', 'introduced', 'progressive web app designed for regions']
# ['Twitter', 'introduced Twitter Lite with', 'size designed for devices']
# ['Twitter', 'introduced Twitter Lite with', 'size designed for devices with storage capacity']
# ['Twitter', 'introduced Twitter Lite with', 'size designed for devices with limited storage capacity']
# ['Twitter', 'introduced', 'web app']
# ['Twitter', 'introduced Twitter Lite with', 'size']
# ['Twitter', 'has limited For', 'many years']
# ['Twitter', 'has limited use For', 'years']
# ['Twitter', 'has limited For', 'years']
# ['Twitter', 'has limited use For', 'many years']
# ['Twitter', 'began In', '2015']
# ['Twitter', 'place', 'focus on streaming video programming']
# ['Twitter', 'place', 'focus on live streaming video programming']
# ['Twitter', 'began In', '2016']
# ['Twitter', 'place', 'larger focus']
# ['Twitter', 'place', 'larger focus on live streaming video programming']
# ['Twitter', 'place', 'focus']
# ['Twitter', 'place', 'larger focus on streaming video programming']
# ['Twitter', 'announced During', 'event']
# ['Twitter', 'announced During', 'event in May 2017']
# ['Twitter', 'announced During', 'event in New York in May 2017']
# ['Twitter', 'announced During', 'event in New York']
# ['Twitter', 'had as of', 'first quarter']
# ['Twitter', 'had as of', 'quarter']
# ['Twitter', 'had as of', 'first quarter of 2017']
# ['Twitter', 'had as of', 'quarter of 2017']
# ['Twitter', 'has offered', 'two methods']
# ['Twitter', 'has offered', 'two different methods']
# ['Twitter', 'archiving', "one 's own Twitter account data"]
# ['Twitter', 'archiving', "one 's Twitter account data"]
# ['Twitter', 'to', '2010 2014 desktop user interface']
# ['Twitter', 'was ranked', '32nd most visited website']
# ['Twitter', 'was ranked globally', '32nd visited website']
# ['Twitter', 'was ranked', 'visited website']
# ['Twitter', 'was ranked', 'website']
# ['Twitter', 'was ranked globally', '32nd most visited website']
# ['Twitter', 'was ranked website by', "Alexa 's web traffic analysis down"]
# ['Twitter', 'was ranked', '32nd visited website']
# ['Twitter', 'was ranked globally', 'visited website']
# ['Twitter', 'was ranked globally', 'most visited website']
# ['Twitter', 'was ranked website by', "Alexa 's web traffic analysis"]
# ['Twitter', 'was ranked website by', "Alexa 's web traffic analysis down from twelfth"]
# ['Twitter', 'was ranked website In', 'mid-September 2019']
# ['Twitter', 'was ranked globally', '32nd website']
# ['Twitter', 'was ranked', '32nd website']
# ['Twitter', 'was ranked globally', 'website']
# ['Twitter', 'was ranked', 'most visited website']
# ['Twitter', 'had', 'user retention rate']
# ['Twitter', 'had', 'monthly user retention rate of forty percent']
# ['Twitter', 'had', 'user retention rate of forty percent']
# ['Twitter', 'had', 'monthly user retention rate']
# ['Twitter', 'had', 'growth of 1,382 percent']
# ['Twitter', 'increasing from', '475,000 visitors in February 2008']
# ['Twitter', 'increasing from', '475,000 visitors']
# ['Twitter', 'had', 'growth']
# ['Twitter', 'increasing to', '7 million']
# ['Twitter', 'increasing from', '475,000 unique visitors in February 2008']
# ['Twitter', 'had', 'annual growth']
# ['Twitter', 'increasing from', '475,000 unique visitors']
# ['Twitter', 'had', 'annual growth of 1,382 percent']
# ['Twitter', 'increasing in', 'February 2009']
# ['Twitter', 'of', 'users']
# ['Twitter', 'to', 'early adopter period']
# ['Twitter', 'announced On', 'September 7']
# ['Twitter', 'leads', 'Facebook']
# ['Twitter', 'announced On', 'March 31 2014']
# ['Twitter', 'is used by', '24 % of online US adults']
# ['Twitter', 'reported', 'losses with revenue']
# ['Twitter', 'reported', 'losses with annual revenue']
# ['Twitter', 'reported', 'losses of US$ 108 million']
# ['Twitter', 'reported losses For', 'year 2017']
# ['Twitter', 'reported', 'losses of US$ 108 million with revenue']
# ['Twitter', 'reported', 'losses']
# ['Twitter', 'reported', 'losses with annual revenue of $ 2.443 billion']
# ['Twitter', 'reported', 'losses of US$ 108 million with annual revenue']
# ['Twitter', 'reported losses For', 'fiscal year 2017']
# ['Twitter', 'reported', 'losses with revenue of $ 2.443 billion']
# ['Twitter', 'is backed by', 'Union Square Ventures']
# ['Twitter', 'is backed by', 'Digital Garage']
# ['Twitter', 'is backed by', 'Spark Capital']
# ['Twitter', 'announced', 'investment']
# ['Twitter', 'announced', 'significant investment led']
# ['Twitter', 'announced investment In', 'August']
# ['Twitter', 'announced', 'significant investment led by Digital Sky Technologies']
# ['Twitter', 'announced', 'investment led by Digital Sky Technologies']
# ['Twitter', 'announced', 'investment led']
# ['Twitter', 'announced', 'significant investment']
# ['Twitter', 'was valued In', '2016']
# ['Twitter', 'was valued by', 'Forbes']
# ['Twitter', 'was valued at', 'US$ 15.7 billion']
# ['Twitter', 'of', 'revenue']
# ['Twitter', 'achieve', 'numbers']
# ['Twitter', 'announced', 'plans']
# ['Twitter', 'announced plans On', 'April 13']
# ['Twitter', 'announced As of', 'April 13']
# ['Twitter', 'announced In', 'June 2011']
# ['Twitter', 'generated', 'US$ 139.5 million in advertising sales']
# ['Twitter', 'generated', 'US$ 139.5 million']
# ['Twitter', 'later reported', 'that']
# ['Twitter', 'reported', 'that']
# ['Twitter', 'continue', 'their advertising campaign']
# ['Twitter', 'announced In', 'April 2013']
# ['Twitter', 'launched', 'Instant Unlock Card']
# ['Twitter', 'places', 'great reliance on open-source software']
# ['Twitter', 'places', 'reliance on open-source software']
# ['Twitter', 'places', 'great reliance']
# ['Twitter', 'places', 'reliance']
# ['Twitter', 'blending', 'its homegrown']
# ['Twitter', 'introduced redesign in', 'September 2010']
# ['Twitter', 'introduced', 'major redesign']
# ['Twitter', 'introduced', 'redesign of its user interface']
# ['Twitter', 'introduced', 'first redesign of its user interface']
# ['Twitter', 'introduced', 'redesign']
# ['Twitter', 'increased focus on', 'inline embedding']
# ['Twitter', 'focus on', 'inline embedding of multimedia content']
# ['Twitter', 'increased focus on', 'inline embedding of multimedia content']
# ['Twitter', 'adopting', 'dual-pane layout with navigation bar along top']
# ['Twitter', 'introduced', 'first major redesign of its user interface']
# ['Twitter', 'introduced', 'first redesign']
# ['Twitter', 'introduced', 'major redesign of its user interface']
# ['Twitter', 'introduced', 'first major redesign']
# ['Twitter', 'focus on', 'inline embedding']
# ['Twitter', 'adopting', 'dual-pane layout']
# ['Twitter', 'adopting', 'dual-pane layout with navigation bar']
# ['Twitter', 'became', 'first right-to-left language versions']
# ['Twitter', 'became', 'first language versions']
# ['Twitter', 'became', 'language versions']
# ['Twitter', 'became', 'available']
# ['Twitter', 'became', 'language versions of site']
# ['Twitter', 'became', 'first right-to-left language versions of site']
# ['Twitter', 'became', 'right-to-left language versions of site']
# ['Twitter', 'became', 'available in Arabic']
# ['Twitter', 'became', 'first language versions of site']
# ['Twitter', 'became', 'right-to-left language versions']
# ['Twitter', 'became In', 'March 2012']
# ['Twitter', 'reducing interface to', 'two columns']
# ['Twitter', 'began', 'migrate']
# ['Twitter', 'reducing', 'interface']
# ['Twitter', 'began In', 'September 2018']
# ['Twitter', 'had', 'approximately ninety-eight percent uptime']
# ['Twitter', 'had', 'percent uptime']
# ['Twitter', 'had', 'ninety-eight percent uptime']
# ['Twitter', 'collects', 'information specified']
# ['Twitter', 'collects', 'personally identifiable information about its users']
# ['Twitter', 'collects', 'personally identifiable information specified in its privacy policy']
# ['Twitter', 'collects', 'personally identifiable information specified']
# ['Twitter', 'collects', 'information specified in its privacy policy']
# ['Twitter', 'collects', 'identifiable information specified in its privacy policy']
# ['Twitter', 'collects', 'identifiable information']
# ['Twitter', 'collects', 'information about its users']
# ['Twitter', 'collects', 'identifiable information about its users']
# ['Twitter', 'collects', 'information']
# ['Twitter', 'collects', 'identifiable information specified']
# ['Twitter', 'collects', 'identifiable information about its users specified']
# ['Twitter', 'collects', 'personally identifiable information']
# ['Twitter', 'collects', 'personally identifiable information about its users specified']
# ['Twitter', 'collects', 'information about its users specified']
# ['Twitter', 'used', 'phone number']
# ['Twitter', 'used', 'phone number of sender of SMS message']
# ['Twitter', 'used', 'phone number of sender']
# ['Twitter', 'introduced', 'optional identification number']
# ['Twitter', 'introduced', 'PIN']
# ['Twitter', 'introduced', 'identification number']
# ['Twitter', 'introduced identification number Within', 'weeks']
# ['Twitter', 'introduced', 'optional personal identification number']
# ['Twitter', 'introduced', 'personal identification number']
# ['Twitter', 'introduced identification number Within', 'few weeks']
# ['Twitter', 'launched', 'beta version of their Verified Accounts']
# ['Twitter', 'launched', 'beta version']
# ['Twitter', 'to', 'security breaches']
# ['Twitter', 'take', 'number']
# ['Twitter', 'take', 'number of steps']
# ['Twitter', 'said in', 'statement']
# ['Twitter', 'notify', 'its users']
# ['Twitter', 'issued', 'statement']
# ['Twitter', 'issued statement at', '13:50 UTC']
# ['Twitter', 'issued', 'statement on their status blog']
# ['Twitter', 'is in', 'Europe']
# ['Twitter', 'accede to', 'UK court order']
# ['Twitter', 'acquired', 'Dasient']
# ['Twitter', 'acquired Dasient in', 'January 2012']
# ['Twitter', 'announced', 'plans']
# ['Twitter', 'later announced at_time', 'month']
# ['Twitter', 'announced at_time', 'month']
# ['Twitter', 'handles with', 'rates of fake followers']
# ['Twitter', 'handles with', 'rates']
# ['Twitter', 'handles with', 'highest rates']
# ['Twitter', 'handles with', 'highest rates of fake followers']
# ['Twitter', 'announced', 'plans']
# ['Twitter', 'Followed', 'sharing of images']
# ['Twitter', 'Followed', 'sharing']
# ['Twitter', 'announced', 'reporting including blocking mechanism devised']
# ['Twitter', 'announced', 'reporting including mechanism devised']
# ['Twitter', 'announced', 'new reporting including mechanism devised by Randi Harper']
# ['Twitter', 'announced', 'reporting including blocking mechanism devised by Randi Harper']
# ['Twitter', 'announced', 'new reporting including mechanism devised']
# ['Twitter', 'announced', 'new reporting including mechanism']
# ['Twitter', 'announced', 'new reporting including blocking mechanism']
# ['Twitter', 'announced', 'reporting including blocking mechanism']
# ['Twitter', 'announced', 'new reporting including blocking mechanism devised']
# ['Twitter', 'announced', 'new reporting']
# ['Twitter', 'announced', 'reporting']
# ['Twitter', 'announced', 'reporting including mechanism']
# ['Twitter', 'announced', 'reporting including mechanism devised by Randi Harper']
# ['Twitter', 'lost users as', 'result']
# ['Twitter', 'lost', 'users']
# ['Twitter', 'creation of', 'Twitter Trust']
# ['Twitter', 'announced On', 'May 10 2019']
# ['Twitter', 'disclosed On', 'May 13 2019']
# ['Twitter', 'only use', 'its patents for defensive purposes']
# ['Twitter', 'use', 'its patents for purposes']
# ['Twitter', 'announced On', 'April 17']
# ['Twitter', 'use', 'its patents']
# ['Twitter', 'only use', 'its patents for purposes']
# ['Twitter', 'only use', 'its patents']
# ['Twitter', 'use', 'its patents for defensive purposes']
# ['Twitter', 'use', 'wrapper']
# ['Twitter', 'use', 't.co wrapper']
# ['Twitter', 'experimenting with', 'its URL']
# ['Twitter', 'used', 'services']
# ['Twitter', 'began', 'experimenting with its URL']
# ['Twitter', 'used', 'services of parties']
# ['Twitter', 'began', 'experimenting']
# ['Twitter', 'experimenting with', 'its own URL']
# ['Twitter', 'began', 'experimenting with its own URL']
# ['Twitter', 'used', 'services of third parties']
# ['Twitter', 'announced On', 'June 7']
# ['Twitter', 'to', 'search']
# ['Twitter', 'provide', 'photo galleries']
# ['Twitter', 'provide', 'photo galleries designed']
# ['Twitter', 'having', 'one of most open of major technology company']
# ['Twitter', 'having', 'one of open of major technology company']
# ['Twitter', 'however made', 'number']
# ['Twitter', 'made', 'number']
# ['Twitter', 'mandated In', '2010']
# ['Twitter', 'launched', 'its own URL shortener']
# ['Twitter', 'launched', 'its URL shortener']
# ['Twitter', 'committed', 'continue']
# ['Twitter', 'continue', 'supporting']
# ['Twitter', 'announced', 'suite of developer tools']
# ['Twitter', 'announced', 'suite of mobile developer tools']
# ['Twitter', 'announced', 'suite of mobile developer tools built around Crashlytics']
# ['Twitter', 'announced', 'suite']
# ['Twitter', 'announced Fabric In', 'October 2014']
# ['Twitter', 'announced', 'suite of mobile developer tools built']
# ['Twitter', 'announced', 'suite of developer tools built']
# ['Twitter', 'announced', 'Fabric']
# ['Twitter', 'announced', 'suite of developer tools built around Crashlytics']
# ['Twitter', 'building', 'Fabric']
# ['Twitter', 'take', "advantage of Crashlytics ' adoption"]
# ['Twitter', 'take', 'advantage']
# ['Twitter', 'take', "advantage of Crashlytics ' large adoption"]
# ['Twitter', 'announced In', 'early 2016']
# ['Twitter', 'government of', 'Iran']
# ['Twitter', 'suspended', 'core group']
# ['Twitter', 'suspended core group During', '2019 Hong Kong bill protests']
# ['Twitter', 'suspended core group During', '2019 Hong Kong anti-extradition bill protests']
# ['Twitter', 'suspended', 'core group of 1,000 fake accounts']
# ['Twitter', 'released In', 'their announcement']
# ['Twitter', 'was sued by', 'widow']
# ['Twitter', 'claiming', 'that']
# ['Twitter', 'was sued by', 'widow of U.S. man killed']
# ['Twitter', 'was sued by', 'widow of U.S. man']
# ['Twitter', 'was sued In', 'January 2016']
# ['Twitter', 'disputed', 'claim']
# ['Twitter', 'sparking', 'protests']
# ['Twitter', 'restored accounts Following', 'outcry']
# ['Twitter', 'restored', 'accounts']
# ['Twitter', 'restored accounts Following', 'public outcry']
# ['Twitter', 'restored accounts at_time', 'next day']
# ['Twitter', 'restored accounts at_time', 'day']
# ['Facebook', 'along with day is', 'Twitter']
# ['Twitter', 'stated In', 'August 2016']
# ['Twitter', 'had identified Between', 'January']
# ['Twitter', 'announced In', 'May 2018']
# ['Twitter', 'announced in', 'response']
# ['Twitter', 'announced in', 'response to scrutiny over misuse']
# ['Twitter', 'announced in', 'response to scrutiny']
# ['Twitter', 'announced in', 'response to scrutiny over misuse by those seeking']
# ['Twitter', 'announced in', 'response to scrutiny over misuse of Twitter']
# ['Twitter', 'announced in', 'response to scrutiny over misuse by those']
# ['Twitter', 'announced In', 'October 2019']
# ['Twitter', 'is banned in', 'Iran']
# ['Twitter', 'been intermittently blocked in', 'countries including Egypt']
# ['Twitter', 'been', 'intermittently blocked']
# ['Twitter', 'is banned in', 'completely Iran']
# ['Twitter', 'been blocked in', 'countries']
# ['Twitter', 'been intermittently blocked in', 'numerous countries including Egypt']
# ['Twitter', 'been intermittently blocked in', 'countries']
# ['Twitter', 'been blocked in', 'numerous countries including Egypt']
# ['Twitter', 'been blocked in', 'countries including Egypt']
# ['Twitter', 'been', 'blocked']
# ['Twitter', 'been intermittently blocked in', 'numerous countries']
# ['Twitter', 'been blocked in', 'numerous countries']
# ['Twitter', 'cooperated In', '2016']
# ['Twitter', 'remove', 'content']
# ['Twitter', 'cooperated with', 'Israeli government']
# ['Twitter', 'remove', 'certain content']
# ['Twitter', 'cooperated with', 'government']
# ['Twitter', 'said In', 'biannual transparency report published on September 19 2017']
# ['Twitter', 'said In', '11th biannual transparency report']
# ['Twitter', 'said In', '11th transparency report published']
# ['Twitter', 'said In', 'transparency report published on September 19 2017']
# ['Twitter', 'said In', '11th transparency report']
# ['Twitter', 'said In', 'biannual transparency report']
# ['Twitter', 'said In', '11th transparency report published on September 19 2017']
# ['Twitter', 'said In', 'biannual transparency report published']
# ['Twitter', 'said In', 'transparency report published']
# ['Twitter', 'said In', 'transparency report']
# ['Twitter', 'said In', '11th biannual transparency report published']
# ['Twitter', 'responded After', 'claims']
# ['Twitter', 'responded After', 'claims in media']
# ['Twitter', 'of', 'Trust']
# ['Twitter', 'remove Donald Trump from', 'platform']
# ['Twitter', 'for', 'real-time functionality']
# ['Twitter', 'has acted as', 'sensor for automatic response']
# ['Twitter', 'has acted In', 'addition']
# ['Twitter', 'has acted as', 'sensor for response to natural disasters']
# ['Twitter', 'has acted as', 'sensor for automatic response to natural disasters']
# ['Twitter', 'has acted as', 'sensor for response to disasters']
# ['Twitter', 'has acted as', 'sensor for automatic response to disasters']
# ['Twitter', 'has acted as', 'sensor for response']
# ['Twitter', 'has acted as', 'sensor']
# ['Twitter', 'is in', 'college courses']
# ['Twitter', 'of', 'appeal']
# ['Twitter', 'won', 'Breakout']
# ['Twitter', 'won', 'Breakout of Year']
# ['Twitter', 'won Breakout In', '2009']
# ['Twitter', 'was named', 'Word of Year']
# ['Twitter', 'was named Word On', 'November 29']
# ['Twitter', 'was named Word by', 'Language Monitor']
# ['Twitter', 'was named', 'Word']
# ['Twitter', 'was named Word by', 'Global Language Monitor']
# ['Twitter', 'of', 'rapid expansion']
# ['Twitter', 'posting in', 'English']
# ['Twitter', 'show', 'his judgement']
# ['Twitter', 'making', 'TV']
# ['Twitter', 'encourage', 'people']
# ['Twitter', 'entered agreement In', 'December 2012']
# ['Twitter', 'entered', 'multi-year agreement']
# ['Twitter', 'entered', 'Nielsen']
# ['Twitter', 'entered', 'agreement']
# ['Twitter', 'acquired Bluefin Labs for', 'US$ 50 million $ 100 million']
# ['Twitter', 'acquired Bluefin Labs for', 'estimated US$ 50 million $ 100 million']
# ['Twitter', 'acquired Bluefin Labs in', 'February 2013']
# ['Twitter', 'acquired', 'Bluefin Labs']
# ['Twitter', 'runs With', 'Amplify']
# ['Facebook', 'introduced', 'number']
# ['Facebook', 'introduced number In', 'attempt']
# ['Facebook', 'introduced number In', "attempt compete with Twitter 's leadership"]
# ['Facebook', 'introduced number In', "attempt compete with Twitter 's leadership in TV"]
# ['Facebook', 'drive', 'conversation']
# ['Facebook', 'introduced number In', 'attempt compete']
# ['Facebook', 'drive', 'conversation about TV']
# ['Facebook', 'drive', 'conversation about TV including hashtags']
# ['Twitter', 'with', 'leadership in TV']
# ['Facebook', 'introduced number in', '2013']
# ['Facebook', 'announced partnership In', 'January 2014']
# ['Facebook', 'announced', 'partnership']
# ['Facebook', 'struck', 'partnership']
# ['Twitter', 'acquiring', 'SecondSync three months']
# ['Twitter', 'acquiring later', 'SecondSync Mesagraph three months']
# ['Twitter', 'acquiring later', 'SecondSync three months']
# ['Twitter', 'acquiring', 'SecondSync Mesagraph three months']
# ['Twitter', 'improve', "firm 's offering to advertisers"]
# ['Twitter', 'was able With', 'additional tools']
# ['Twitter', 'allowing', 'them']
# ['Twitter', 'was able With', 'additional analytic tools']
# ['Twitter', 'improve', "firm 's offering"]
# ['Twitter', 'was able With', 'tools']
# ['Twitter', 'was able With', 'analytic tools']
# ['Twitter', 'acquired', 'its Amplify partner in U.S.']
# ['Twitter', 'acquired', 'its Amplify partner']
# ['Twitter', 'announced In', 'July 2017']
# ['Twitter', 'proved', 'largest source']
# ['Twitter', 'proved with', 'over 40 million tweets']
# ['Twitter', 'proved On', 'day of 2016 U.S. election']
# ['Twitter', 'proved On', 'day of 2016 U.S. presidential election']
# ['Twitter', 'proved', 'source of breaking news']
# ['Twitter', 'be source of', 'breaking news']
# ['Twitter', 'proved', 'source']
# ['Twitter', 'proved with', 'over 40 million tweets sent']
# ['Twitter', 'proved', 'largest source of breaking news']
# ['Twitter', 'proved On', 'day']
# ['Twitter', 'be largest source of', 'breaking news']

# %%
# Manual inspection revealed these as better triple candidates
'''
['Twitter', 'was created in', 'March 2006']
['Jack Dorsey', 'student at', 'New York University']
['Twitter', 'acquired', 'Crashlytics']
['Twitter', 'acquired', 'Trendrr']
['Twitter', 'announced', 'partnership with IBM']
['Twitter', 'announced', 'its acquisition of Periscope']
['Twitter', 'is backed by', 'Union Square Ventures']
['Twitter', 'is backed by', 'Digital Garage']
['Twitter', 'is backed by', 'Spark Capital']
['Twitter', 'became', 'available in Arabic']
['Twitter', 'is banned in', 'Iran']
['Twitter', 'been blocked in', 'countries including Egypt']
['Twitter', 'acquiring', 'SecondSync three months']
['Twitter', 'acquired Bluefin Labs for', 'US$ 50 million $ 100 million']
'''
# Out:
# "\n['Twitter', 'was created in', 'March 2006']\n['Jack Dorsey', 'student at', 'New York University']\n['Twitter', 'acquired', 'Crashlytics']\n['Twitter', 'acquired', 'Trendrr']\n['Twitter', 'announced', 'partnership with IBM']\n['Twitter', 'announced', 'its acquisition of Periscope']\n['Twitter', 'is backed by', 'Union Square Ventures']\n['Twitter', 'is backed by', 'Digital Garage']\n['Twitter', 'is backed by', 'Spark Capital']\n['Twitter', 'became', 'available in Arabic']\n['Twitter', 'is banned in', 'Iran']\n['Twitter', 'been blocked in', 'countries including Egypt']\n['Twitter', 'acquiring', 'SecondSync three months']\n['Twitter', 'acquired Bluefin Labs for', 'US$ 50 million $ 100 million']\n"

# %%
# Formatted Candidates
new_entities = [
    ['Twitter', 'created_in', 'March 2006'],
    ['Jack Dorsey', 'studied_at', 'New York University'],
    ['Twitter', 'acquired', ['Crashlytics', 'Trendrr', 'SecondSync', 'Bluefin Labs']],
    ['Twitter', 'partners', ['IBM']],
    ['Twitter', 'backers', ['Union Square Ventures', 'Digital Garage', 'Spark Capital']],
    ['Twitter', 'banned_in', ['Iran', 'Egypt']]
]

# %%
entities = {}
with open('../wiki_crawler/entities.json') as fh:
    for entity in fh.readlines():
        entity_data = json.loads(entity)
        entities[entity_data['name']] = entity_data

# %%
for new_e in new_entities:
    entities[new_e[0]][new_e[1]] = new_e[2]

# %%
# !rm all_entities.json

# %%
# Update file with all entities
with open('all_entities.json', 'w') as fh:
    for key, entity in entities.items():
        json.dump(entity, fh)
        fh.write('\n')
